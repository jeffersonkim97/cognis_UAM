# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rn
import shapely
import json
from shapely import geometry
import time

# 3D Plot
from mpl_toolkits import mplot3d

# Custom Classes
from SE2_Legacy import SE2, se2
from Camera import Camera
from Dynamic import DynamicMap

# %%
# Global functions
def SE2_log(M):
    """
    Matrix logarithm for SE2 Lie group
    """
    theta = np.arctan2(M[1, 0], M[0, 0])
    if np.abs(theta) < 1e-6:
        A = 1 - theta**2/6 + theta**4/120
        B = theta/2 - theta**3/24 + theta**5/720
    else:
        A = np.sin(theta)/theta
        B = (1 - np.cos(theta))/theta
    V_inv = np.array([[A, B], [-B, A]])/(A**2 + B**2)
    t = M[:2, 2]
    u = V_inv.dot(t)
    return np.array([u[0], u[1], theta])

def SE2_exp(v):
    """
    SE2 matrix exponential
    """
    x, y, theta = v
    if np.abs(theta) < 1e-6:
        A = 1 - theta**2/6 + theta**4/120
        B = theta/2 - theta**3/24 + theta**5/720
    else:
        A = np.sin(theta)/theta
        B = (1 - np.cos(theta))/theta
    V = np.array([[A, -B], [B, A]])
    R = np.array([
        [np.cos(theta), -np.sin(theta)],
        [np.sin(theta), np.cos(theta)]])
    u = np.array([[x, y]]).T
    return np.block([
        [R, V.dot(u)],
        [0, 0,  1]])

def SE2_to_param(M):
    """
    From matrix to [theta, x, y]
    """
    theta = np.arctan2(M[1, 0], M[0, 0])
    x = M[0, 2]
    y = M[1, 2]
    return np.array([x, y, theta])

# %%
# R2T2
class R2T2:
    """
    RRT with Time Domain

    TODO
    1. Complete 2D RRT
    1.1 Build RRT with SE2
    2. Complete 3D RRTs
    """
    
    def __init__(self, x0, x1, t, vehicle, map_in):
        # x: 2x1 vector, [xinit, xfin]
        xi_x = x0[0]
        xi_y = x0[1]
        self.thet_init = x0[2]
        self.xinit = (xi_x, xi_y, self.thet_init)
        xf_x = x1[0]
        xf_y = x1[1]
        self.thet_fin = x1[2]
        self.xfin = (xf_x, xf_y, self.thet_fin)
        
        # t: 3x1 vector, [trange, delt, endtime]
        self.trange = t[0]
        self.delt = t[1]
        self.endtime = t[2]
        
        # vehcile: dictionary
        # key: v
        # 'v' = max velocity
        # 'radius' = radius
        self.vmax = vehicle['v']
        self.vrad = vehicle['radius']

        # map: dictionary
        # key: n, st, dy, curr
        # 'n' = repeat period length
        # 'ncam' = number of camera present
        # 'st' = static map
        # ['st']['size'] = 4x1 vector [x0, xmax, y0, ymax]
        # ['st']['n'] = number of buildings
        # ['st'][str(i)], i = number // building poly  at ith index
        # 'dy' = repeating dynamic map with n periods
        # ['dy'][str(i)], i = number // dynamic map at ith index
        # 'curr' = static + dynamic = current map
        # ['curr'][str(i)], i = number = currnet map at ith index
        self.map_st = map_in['st']
        self.map_dy = map_in['dy']
        #self.map_period = map_in['n']
        #self.map_curr = map_in['curr']

    # Functios for Step 3
    def gen_node(self, r, qnear, c, t_in):
        count = c

        # Generate qrand
        # This is polar method
        qrand_r = rn.uniform(0, r)
        qrand_th = rn.uniform(0, 2*np.pi)
        qrand_x = qrand_r*np.cos(qrand_th)
        qrand_y = qrand_r*np.sin(qrand_th)
        qrand = np.array([qrand_x+qnear[0], qrand_y+qnear[1], qrand_th])
        Qrand_SE2 = SE2(qrand[0], qrand[1], qrand[2])

        if c <= 100:
            if self.static_bound(qrand) and not Qrand_SE2 is None and not self.dynamic_bound(qrand, t_in):
                return Qrand_SE2
            else:
                count+=1
                return self.gen_node(r,qnear, count, t_in)
        else:
            # If loop is too much, just return stationary
            return SE2(qnear[0], qnear[1], qnear[2])
        
    def building_bound(self, xi):
        # Check if point is inside building polygon
        smap = self.map_st
        check_vec = []
        for i in range(smap['n']):
            # ibuilding is a list of vertex of building polygon
            ibuilding = smap[str(i)]
            wall = geometry.LineString(ibuilding)
            building = geometry.Polygon(wall)

            check_vec.append(building.contains(geometry.Point(xi[0],xi[1])))

        # Add all boolean values,
        # if 1: Point inside building
        # if 0: Point not contained within building
        return np.sum(check_vec)

    def move_bound(self, r, xi):
        # Is xi within possible movement range in given time?
        return bool(xi[0]**2+xi[1]**2 <= r)

    def in_map(self, xi):
        # Check if ponit is within map
        return (xi[0] >= self.map_st['size'][0] and xi[0]<=self.map_st['size'][1] and xi[1] >= self.map_st['size'][2] and xi[1]<=self.map_st['size'][3])

    def static_bound(self, xi):
        return self.in_map(xi) and not self.building_bound(xi)
    
    def dynamic_bound(self, xi, t_in):
        """
        1. At given time input t_in, obtain dynamic masking.
        2. Then, check whether or not that given piont is inside any camera FOV
        Input: t_in = time index (continuous)
        Output: Dynamic masking at that point
        """
        # Continuous Dynamic Map function is generated during setup phase
        dmap = self.map_dy

        # Extract camera function dictionary
        # Camera function has following keys
        # ['n'] = number of camera
        # [str(i)]['Camera'] = ith camera object
        # [str(i)]['FOV'] = Computed camera FOV triangle vertices
        # [str(i)]['FOV_Poly'] = Computed polygon object from FOV vertices
        cameras = dmap.gen_cam(t_in)
        ncam = cameras['n']
        check_vec = []
        for i in range(ncam):
            # Extract FOV Polynomial of ith camera
            cam_i = cameras[str(i)]['FOV_Poly']
            check_vec.append(cam_i.contains(geometry.Point(xi[0],xi[1])))
        
        # Add all boolean values,
        # if 1: Point inside any camera FOVs
        # if 0: Point is outside of all camera FOVs
        return np.sum(check_vec)

    # Functions for Step 4
    def nearest(self, G, xi):
        3# Find nearest vertex
        range_vec = []
        for ii in range(len(G['vertex'])):
            VERT_avail = G['vertex'][ii]
            vert_avail = VERT_avail.SE2param()
            temp = G['t'][ii]
            range_vec.append(np.sqrt((xi[0] - vert_avail[0])**2 + (xi[1] - vert_avail[1])**2))

        Xnear = G['vertex'][range_vec.index(min(range_vec))]
        t_at_Xnear = G['t'][range_vec.index(min(range_vec))]

        return Xnear, t_at_Xnear
    
    # Functions for Step 5
    def find_u_R_d(self, X0, X1):
        # Compute arc length, radius, distance
        M = X0.inv()@X1.matrix()
        dx, dy, dth = SE2_to_param(M)

        d = np.sqrt(dx**2 + dy**2)
        alpha = np.arctan2(dy, dx)

        if np.abs(alpha) > 1e-3:
            R = d/(2*np.sin(alpha))
            u = 2*R*alpha
        else:
            R = np.infty
            u = d

        return u, R, d

    def local_path_planner(self, X0, X1, dist):
        # Plot route from start X0 to end X1
        u, R, d = self.find_u_R_d(X0, X1)
        if np.abs(u) > dist:
            u = dist*np.sign(u)

        # Compute turn angle omega
        if np.isclose(np.abs(R),0):
            omega = 0
        else:
            omega = u/R

        v = se2(u, 0, omega)
        V = v.exp()

        return X0.matrix()@V
    
    def distance_R2T2(self, ti, X0, X1):
        u, R, d = self.find_u_R_d(X0, X1)
        cost = self.vmax*ti
        if d > 0.1 and np.abs(R) < 0.5:
            cost = np.infty
        
        if u < 0:
            cost = np.infty
        return cost
    
    def current_pos(self, Q0, Q1, V, qt_vec):
        """
        TODO
        If current_pos is outside of bounds
        -> return to position where it is valid
        """
        v = SE2_log(Q0.inv()@V)
        curr_path = {}
        curr_path['x'] = []
        curr_path['y'] = []
        curr_path['t'] = []
        curr_path['theta'] = []
        tscale = qt_vec[-1]-qt_vec[0]

        #for tt in np.arange(0,1,self.delt):
        # for tt in np.linspace(0, 1, len(qt_vec)):
        for tt in np.linspace(0, 1, 100):
        #for tt in np.linspace(0,qt_vec[-1]-qt_vec[0],len(qt_vec)):
            Q = Q0.matrix()@(SE2_exp(v*tt))
            xt, yt, thetat = SE2_to_param(Q)
            curr_path['x'].append(xt)
            curr_path['y'].append(yt)
            curr_path['t'].append(qt_vec[0]+tscale*tt)
            curr_path['theta'].append(thetat)

            # Check if current position is on collision point
            if self.collision_check(self.vrad, Q0, Q, [tt], 1):
                return SE2(x=xt, y=yt, theta=thetat), curr_path
            
        return SE2(x=xt, y=yt, theta=thetat), curr_path
    
    def collision_check(self, vehicle_radius, Q0, Q1, qtvec, steps):
        """
        TODO
        Add collision for dynamic case
        """
        V = Q0.inv()@(Q1)
        v = SE2_log(V)
        test_vector = np.linspace(0,1,steps)
        for tt in test_vector:
            Q = Q0.matrix()@(SE2_exp(v*tt))
            xt, yt, thetat = SE2_to_param(Q)
            
            # check map bounds
            if not self.in_map([xt, yt, thetat]):
                return True

            # check collision with static obstacles
            if self.in_map([xt, yt, thetat]):                
                if bool(self.building_bound([xt, yt, thetat])):
                    return True
            # check collision with dynamic obstacles at matching time in time vector qtvec
            t_in_to_test, = np.where(test_vector == tt)
            t_to_test = qtvec[t_in_to_test[0]]
            if bool(self.dynamic_bound((xt, yt), t_to_test)):
                return True
        return False
    
    # Functions for Step 6
    def get_range(self, Q, Xf):
        diff = Xf.matrix() - Q.matrix()
        return np.sqrt((diff[0,2])**2 + (diff[1,2])**2)
    
    # Functions for Step 7
    def rrt_course(self, G):
        # print('Plotting Course')
        neighbor = G['neighbor']
        key_list = neighbor.keys()

        # Route Index
        route = []

        def match_vertex(v0, v1):
            tol = 1e-2
            if np.abs(v0[0]-v1[0])<tol and np.abs(v0[1]-v1[1])<tol:
                return True
            else:
                return False

        # Start from initial point
        # points in se3
        q0 = self.xinit
        qf = self.xfin
        qcheck = qf

        # Find matching vertices
        castellan = True
        while castellan:
            # print('Blessing the Machine...')
            for ii in range(len(key_list)):
                # Extract iith key
                currkey = list(key_list)[ii]
                if match_vertex(qcheck, neighbor[str(currkey)][1]):
                    route.append(ii)
                    qcheck = neighbor[str(currkey)][0]
                    # Return route to final point
                    if match_vertex(qcheck, q0):
                        castellan = False
                        return route
                    
    def R2T2_2D(self, compTimeLimit, switch):
        """
        This a 2D RRT with time domain as z axis
        1. Generate Random t
        2. Find range of r it can reach
        3. Generate random coordinate x1, and check whether or not it is located inside the cone, and find closest qnear // Or can we select any number within cone volume?
           80% to move to new qrand
           10% to stay
           10% to move to final point
        4. IF x1 is located inside code, connect it with start point x0 // IF x1 NOT located in cone, regen random coordinate
        5. Can there be path generated?
        6. Repeat 3-4 until cone include final point
        7. Connect from xfin to xinit and generate path
        """
        # Initial Variables
        xi = self.xinit
        xf = self.xfin
        dt = self.delt
        trange = self.trange
        final_path_length = 0
        final_path_time = 0
        # Set Emptry Storages
        # Vertex:
        # Edge: 
        # t: 
        G = {}
        G['vertex'] = []
        G['neighbor'] = {}
        G['edge'] = {}
        G['route'] = []
        G['t'] = []
        
        # Initialize R2T2
        Xi = SE2(x=xi[0], y=xi[1], theta=xi[2])
        Xf = SE2(x=xf[0], y=xf[1], theta=xf[2])
        Qnear = SE2(x=xi[0], y=xi[1], theta=xi[2])
        G['vertex'].append(Qnear)
        G['t'].append(0)
        Qnear_prev = G['vertex'][-1]
        tprev = 0
        map_size = self.map_st['size']
        dmap = self.map_dy
        bad_path = []

        # Start loop, and repeat until route toward final point
        repeat_R2T2 = True
        debug = False
        counter = 0

        # End condition
        dist_best = self.get_range(Xi, Xf)
        dist_tol = 1e-1

        execution_time_vec = {}
        execution_time_vec['Sampling'] = []
        execution_time_vec['NearestNode'] = []
        execution_time_vec['RouteCheck'] = []
        execution_time_vec['CollisoinCheck'] = []
        execution_time_vec['CurrPos'] = []

        start = time.time()
        while repeat_R2T2:
            # Step 1
            # Generate random time t to move
            ti = rn.uniform(0,trange)

            # Step 2
            # Compute possible movement range
            mv_R = self.vmax*ti

            # Step 3
            # Choose next move qnext
            # 80% -> move to random point qrand
            # 10% -> remain stationary
            # 10% -> route to final point
            if not debug:
                # switch = [.8, .1, .1]
                Qnear = None
                Qnear_exist = False
                # print(bool(Qnear_exist))
                sample_start = time.time()
                while not Qnear_exist:
                    if Qnear is None:
                        choose = rn.uniform(0,1)
                        if choose >= 0 and choose <= switch[0]:
                            # Get random point x1, and check whether or not it is valid
                            Qnext = self.gen_node(mv_R, Qnear_prev.SE2param(), 0, tprev)
                            Qnear_exist = True
                        elif choose > switch[0] and choose <= (switch[0]+switch[1]) and switch[1] > 0:                       
                            Qnext = Qnear_prev
                            Qnear_exist = True
                        else:
                            Qnext = SE2(xf[0], xf[1], xf[2])
                            Qnear_exist = True
                execution_time_vec['Sampling'].append(time.time()-sample_start)
                
                # Step 4
                # Find cloest point from qnear
                nearest_start = time.time()
                Qnear, tnear = self.nearest(G, Qnext.SE2param())
                tnext = tnear+ti
                execution_time_vec['NearestNode'].append(time.time()-nearest_start)
                
            # print('Qnear ', Qnear.SE2param())
            # print('Qnext ', Qnext.SE2param())
            # print('trange ', trange)
            # print('ti ', ti)
            # print('tnear ', tnear)
            # print('tnext ', tnext)
            st_tvec = np.arange(tnear, tnext, self.delt)

            # Step 5
            # Generate Path and check collision
            # This is done in SE2 Lie Group for 2D R2T2
            # cost_R2T2 = self.distance_R2T2(ti, Qnear, Qnext)
            route_start = time.time()
            Qroute = self.local_path_planner(Qnear, Qnext, self.vmax*ti)
            execution_time_vec['RouteCheck'].append(time.time()-route_start)
            #Qroute = self.local_path_planner(Qnear, Qnext, cost_R2T2)

            # Check Collision
            # If collision occur, we ignore that path
            # If collision doesn't occur, carry on
            # if self.collision_check(self.vrad, Qnear, Qroute, st_tvec, len(st_tvec)):
            collision_check_start = time.time()
            collision_checked = self.collision_check(self.vrad, Qnear, Qroute, st_tvec, len(st_tvec))
            execution_time_vec['CollisoinCheck'].append(time.time()-collision_check_start)
            if collision_checked:
                bad_path.append(Qnext)
                # print('Route Collision Detected')
            #    print('Route: ', SE2_to_param(Qroute))
            else:
                # Compute current position as time may differ
                curr_pos_start = time.time()
                Qcurr, path_curr = self.current_pos(Qnear, Qnext, Qroute, st_tvec)
                execution_time_vec['CurrPos'].append(time.time()-curr_pos_start)

            # Step 6
            # Check if destination is reached
            # Update Dictionary
                a = Qnear.SE2param()
                b = Qcurr.SE2param()
                edge = [a[0], b[0]], [a[1], b[1]], [tnear, tnear+ti]
                G['vertex'].append(Qcurr)
                G['edge'][str(counter)] = path_curr
                G['neighbor'][str(counter)] = [(a[0], a[1], tnear), (b[0], b[1], tnear + ti)]
                G['t'].append(tnear + ti)

            # Update termination condition
                dist_curr = self.get_range(Qcurr, Xf)
                if dist_curr < dist_best:
                    dist_best = dist_curr
                    Qnear_prev = Qcurr
                    tprev = tnear+ti
                    final_path_length += dist_best
                    final_path_time += ti

            # If within tolerance, we stop and return path
                if dist_best < dist_tol:
                    # print('Destination Reached')
                    # Stop iteration
                    # repeat_R2T2 = False

                    # # Find route to Final Point
                    # route = self.rrt_course(G)
                    # G['route'] = route
                    # route_tvec = []
                    # for ri in np.flip(route):
                    #     route_tvec.append(G['t'][ri])
                    # route_tvec.append(tnext)
                    
                    # with open('R2T2.txt', 'w') as R2T2_output:
                    #     R2T2_output.write(json.dumps(G))
                    return 1, time.time() - start, execution_time_vec, final_path_length, final_path_time #, G
            # If not, we update for next loop
            counter += 1

            # Break out if loop is too long
            if np.abs(G['t'][-1]-self.endtime) <= 1e-1 or (time.time()-start) >= compTimeLimit:
                # print('Fail to reach destination in time')
                return 0, time.time()-start, execution_time_vec, final_path_length, final_path_time #, G

# %%
# Test case
# Initial, Final Positions
x0 = np.array([0, 0, 0])
x1 = np.array([8, 0, 0])
t = [200, .25, 500]

# Vehicle Spec
vehicle = {}
vehicle['v'] = 1.5
vehicle['radius'] = 0.5

# Map
map_in = {}
# Static Map
map_in['st'] = {}
map_in['st']['size'] = np.array([-5, 15, -15, 15])
# Single buliding example
map_in['st']['n'] = 1
map_in['st']['0'] = np.array([
    (2.5,5), (7.5,10), (7.5,-10), (2.5,-5)
])

# Dynamic Map
# This is a continuous function generates camera FOV coverages
# Input is map_in, and time input t_in
map_in['n'] = t[0]
map_in['ncam'] = 1

# Single camera example, surveying final location xfin
# Camera Position
cam_x = np.array([7.5])
cam_y = np.array([rn.uniform(-5, 5)])
cam_dict = {}
cam_dict['n'] = len(cam_x)
cam_dict['x'] = cam_x
cam_dict['y'] = cam_y

# Camera Spec
tilt_limit = np.array([np.pi, 0]) #[upper, lower]
fov_ang = np.deg2rad(20)
fov_rng = 7.5 #[m]
cam_period = t[0]
cam_increment = t[1]
cam_dict['spec'] = {}
cam_dict['spec']['bound'] = tilt_limit
cam_dict['spec']['fov'] = [fov_ang, fov_rng]
cam_dict['spec']['cam_time'] = [cam_period, cam_increment]

# Test dynamic map
dmap = DynamicMap(map_in, cam_dict)
map_in['dy'] = dmap

test = R2T2(x0, x1, t, vehicle, map_in)

# %%
# path_obtained_waitGo, compTime_waitGo, exec_time_dict, final_path_length, final_path_time = test.R2T2_2D(10, [.8, .1, .1])
# print(bool(path_obtained_waitGo))
# print(compTime_waitGo)
# print(final_path_length)
# print(final_path_time)
# Out:
# False
# 10.038871765136719
# 51.69319149295374
# 1220.9857292958764

# %%
mc_iter = 200
K = 7
compTimeVec = [0.1, 1, 3, 5, 7, 9, 10, 15, 20, 25, 30, 35, 40, 45, 50]
# compTimeVec = [0.1, 1, 5, 10]
print(compTimeVec)
print(2*np.sum(compTimeVec)*mc_iter/3600)
# Out:
# [0.1, 1, 3, 5, 7, 9, 10, 15, 20, 25, 30, 35, 40, 45, 50]
# 32.78888888888889

# %%
wait_switch = [.8, .1, .1]
RRTC_switch = [0.95, 0, 0.05]
success_vec_waitGo = []
success_vec_RRTC = []
avg_compTime_vec_waitGo = []
avg_compTime_vec_RRTC = []

WG_path = {}
WG_path['length'] = {}
WG_path['time'] = {}
RRTC_path = {}
RRTC_path['length'] = {}
RRTC_path['time'] = {}

ti_counter = 0
for ti in compTimeVec:
    # Single camera example, surveying final location xfin
    # Camera Position
    cam_x = np.array([7.5])
    # cam_y = np.array([rn.uniform(-10, 10)])
    cam_y = np.array([rn.uniform(-5, 5)])
    cam_dict = {}
    cam_dict['n'] = len(cam_x)
    cam_dict['x'] = cam_x
    cam_dict['y'] = cam_y

    # Camera Spec
    tilt_limit = np.array([np.pi, 0]) #[upper, lower]
    fov_ang = 20#np.deg2rad(rn.uniform(10, 30))
    fov_rng = 7.5 #[m]
    cam_period = t[0]
    cam_increment = t[1]
    cam_dict['spec'] = {}
    cam_dict['spec']['bound'] = tilt_limit
    cam_dict['spec']['fov'] = [fov_ang, fov_rng]
    cam_dict['spec']['cam_time'] = [cam_period, cam_increment]

    start = time.time()
    success_waitGo = 0
    success_RRTC = 0
    counter = 0
    WG_path_length_list = []
    WG_path_time_list = []
    RRTC_path_length_list = []
    RRTC_path_time_list = []
    for mc_ii in range(mc_iter):
        print('iter: '+ str(counter) + ' Computation Time: ' + str(ti))
        # path_obtained, RRTWait = test.R2T2_2D(ti, wait_switch)
        path_obtained_waitGo, compTime_waitGo, WG_exec_time_dict, WG_path_length, WG_path_time = test.R2T2_2D(ti, wait_switch)
        success_waitGo += path_obtained_waitGo
        if path_obtained_waitGo:
            WG_path_length_list.append(WG_path_length)
            WG_path_time_list.append(WG_path_time)

        path_obtained_RRTC, compTime_RRTC, RRTC_exec_time_dict, RRTC_path_length, RRTC_path_time = test.R2T2_2D(ti, RRTC_switch)
        success_RRTC += path_obtained_RRTC
        if path_obtained_RRTC:
            RRTC_path_length_list.append(RRTC_path_length)
            RRTC_path_time_list.append(RRTC_path_time)

        counter += 1
    success_vec_waitGo.append(success_waitGo/mc_iter)
    success_vec_RRTC.append(success_RRTC/mc_iter)
    print('total time spent: ', time.time()-start)
    avg_compTime_vec_waitGo.append(compTime_waitGo)
    avg_compTime_vec_RRTC.append(compTime_RRTC)
    
    WG_path['length'][str(ti_counter)] = WG_path_length_list
    WG_path['time'][str(ti_counter)] = WG_path_time_list
    RRTC_path['length'][str(ti_counter)] = RRTC_path_length_list
    RRTC_path['time'][str(ti_counter)] = RRTC_path_time_list

    ti_counter += 1
# Out:
# iter: 0 Computation Time: 0.1
# iter: 1 Computation Time: 0.1
# iter: 2 Computation Time: 0.1
# iter: 3 Computation Time: 0.1
# iter: 4 Computation Time: 0.1
# iter: 5 Computation Time: 0.1
# iter: 6 Computation Time: 0.1
# iter: 7 Computation Time: 0.1
# iter: 8 Computation Time: 0.1
# iter: 9 Computation Time: 0.1
# iter: 10 Computation Time: 0.1
# iter: 11 Computation Time: 0.1
# iter: 12 Computation Time: 0.1
# iter: 13 Computation Time: 0.1
# iter: 14 Computation Time: 0.1
# iter: 15 Computation Time: 0.1
# iter: 16 Computation Time: 0.1
# iter: 17 Computation Time: 0.1
# iter: 18 Computation Time: 0.1
# iter: 19 Computation Time: 0.1
# iter: 20 Computation Time: 0.1
# iter: 21 Computation Time: 0.1
# iter: 22 Computation Time: 0.1
# iter: 23 Computation Time: 0.1
# iter: 24 Computation Time: 0.1
# iter: 25 Computation Time: 0.1
# iter: 26 Computation Time: 0.1
# iter: 27 Computation Time: 0.1
# iter: 28 Computation Time: 0.1
# iter: 29 Computation Time: 0.1
# iter: 30 Computation Time: 0.1
# iter: 31 Computation Time: 0.1
# iter: 32 Computation Time: 0.1
# iter: 33 Computation Time: 0.1
# iter: 34 Computation Time: 0.1
# iter: 35 Computation Time: 0.1
# iter: 36 Computation Time: 0.1
# iter: 37 Computation Time: 0.1
# iter: 38 Computation Time: 0.1
# iter: 39 Computation Time: 0.1
# iter: 40 Computation Time: 0.1
# iter: 41 Computation Time: 0.1
# iter: 42 Computation Time: 0.1
# iter: 43 Computation Time: 0.1
# iter: 44 Computation Time: 0.1
# iter: 45 Computation Time: 0.1
# iter: 46 Computation Time: 0.1
# iter: 47 Computation Time: 0.1
# iter: 48 Computation Time: 0.1
# iter: 49 Computation Time: 0.1
# iter: 50 Computation Time: 0.1
# iter: 51 Computation Time: 0.1
# iter: 52 Computation Time: 0.1
# iter: 53 Computation Time: 0.1
# iter: 54 Computation Time: 0.1
# iter: 55 Computation Time: 0.1
# iter: 56 Computation Time: 0.1
# iter: 57 Computation Time: 0.1
# iter: 58 Computation Time: 0.1
# iter: 59 Computation Time: 0.1
# iter: 60 Computation Time: 0.1
# iter: 61 Computation Time: 0.1
# iter: 62 Computation Time: 0.1
# iter: 63 Computation Time: 0.1
# iter: 64 Computation Time: 0.1
# iter: 65 Computation Time: 0.1
# iter: 66 Computation Time: 0.1
# iter: 67 Computation Time: 0.1
# iter: 68 Computation Time: 0.1
# iter: 69 Computation Time: 0.1
# iter: 70 Computation Time: 0.1
# iter: 71 Computation Time: 0.1
# iter: 72 Computation Time: 0.1
# iter: 73 Computation Time: 0.1
# iter: 74 Computation Time: 0.1
# iter: 75 Computation Time: 0.1
# iter: 76 Computation Time: 0.1
# iter: 77 Computation Time: 0.1
# iter: 78 Computation Time: 0.1
# iter: 79 Computation Time: 0.1
# iter: 80 Computation Time: 0.1
# iter: 81 Computation Time: 0.1
# iter: 82 Computation Time: 0.1
# iter: 83 Computation Time: 0.1
# iter: 84 Computation Time: 0.1
# iter: 85 Computation Time: 0.1
# iter: 86 Computation Time: 0.1
# iter: 87 Computation Time: 0.1
# iter: 88 Computation Time: 0.1
# iter: 89 Computation Time: 0.1
# iter: 90 Computation Time: 0.1
# iter: 91 Computation Time: 0.1
# iter: 92 Computation Time: 0.1
# iter: 93 Computation Time: 0.1
# iter: 94 Computation Time: 0.1
# iter: 95 Computation Time: 0.1
# iter: 96 Computation Time: 0.1
# iter: 97 Computation Time: 0.1
# iter: 98 Computation Time: 0.1
# iter: 99 Computation Time: 0.1
# iter: 100 Computation Time: 0.1
# iter: 101 Computation Time: 0.1
# iter: 102 Computation Time: 0.1
# iter: 103 Computation Time: 0.1
# iter: 104 Computation Time: 0.1
# iter: 105 Computation Time: 0.1
# iter: 106 Computation Time: 0.1
# iter: 107 Computation Time: 0.1
# iter: 108 Computation Time: 0.1
# iter: 109 Computation Time: 0.1
# iter: 110 Computation Time: 0.1
# iter: 111 Computation Time: 0.1
# iter: 112 Computation Time: 0.1
# iter: 113 Computation Time: 0.1
# iter: 114 Computation Time: 0.1
# iter: 115 Computation Time: 0.1
# iter: 116 Computation Time: 0.1
# iter: 117 Computation Time: 0.1
# iter: 118 Computation Time: 0.1
# iter: 119 Computation Time: 0.1
# iter: 120 Computation Time: 0.1
# iter: 121 Computation Time: 0.1
# iter: 122 Computation Time: 0.1
# iter: 123 Computation Time: 0.1
# iter: 124 Computation Time: 0.1
# iter: 125 Computation Time: 0.1
# iter: 126 Computation Time: 0.1
# iter: 127 Computation Time: 0.1
# iter: 128 Computation Time: 0.1
# iter: 129 Computation Time: 0.1
# iter: 130 Computation Time: 0.1
# iter: 131 Computation Time: 0.1
# iter: 132 Computation Time: 0.1
# iter: 133 Computation Time: 0.1
# iter: 134 Computation Time: 0.1
# iter: 135 Computation Time: 0.1
# iter: 136 Computation Time: 0.1
# iter: 137 Computation Time: 0.1
# iter: 138 Computation Time: 0.1
# iter: 139 Computation Time: 0.1
# iter: 140 Computation Time: 0.1
# iter: 141 Computation Time: 0.1
# iter: 142 Computation Time: 0.1
# iter: 143 Computation Time: 0.1
# iter: 144 Computation Time: 0.1
# iter: 145 Computation Time: 0.1
# iter: 146 Computation Time: 0.1
# iter: 147 Computation Time: 0.1
# iter: 148 Computation Time: 0.1
# iter: 149 Computation Time: 0.1
# iter: 150 Computation Time: 0.1
# iter: 151 Computation Time: 0.1
# iter: 152 Computation Time: 0.1
# iter: 153 Computation Time: 0.1
# iter: 154 Computation Time: 0.1
# iter: 155 Computation Time: 0.1
# iter: 156 Computation Time: 0.1
# iter: 157 Computation Time: 0.1
# iter: 158 Computation Time: 0.1
# iter: 159 Computation Time: 0.1
# iter: 160 Computation Time: 0.1
# iter: 161 Computation Time: 0.1
# iter: 162 Computation Time: 0.1
# iter: 163 Computation Time: 0.1
# iter: 164 Computation Time: 0.1
# iter: 165 Computation Time: 0.1
# iter: 166 Computation Time: 0.1
# iter: 167 Computation Time: 0.1
# iter: 168 Computation Time: 0.1
# iter: 169 Computation Time: 0.1
# iter: 170 Computation Time: 0.1
# iter: 171 Computation Time: 0.1
# iter: 172 Computation Time: 0.1
# iter: 173 Computation Time: 0.1
# iter: 174 Computation Time: 0.1
# iter: 175 Computation Time: 0.1
# iter: 176 Computation Time: 0.1
# iter: 177 Computation Time: 0.1
# iter: 178 Computation Time: 0.1
# iter: 179 Computation Time: 0.1
# iter: 180 Computation Time: 0.1
# iter: 181 Computation Time: 0.1
# iter: 182 Computation Time: 0.1
# iter: 183 Computation Time: 0.1
# iter: 184 Computation Time: 0.1
# iter: 185 Computation Time: 0.1
# iter: 186 Computation Time: 0.1
# iter: 187 Computation Time: 0.1
# iter: 188 Computation Time: 0.1
# iter: 189 Computation Time: 0.1
# iter: 190 Computation Time: 0.1
# iter: 191 Computation Time: 0.1
# iter: 192 Computation Time: 0.1
# iter: 193 Computation Time: 0.1
# iter: 194 Computation Time: 0.1
# iter: 195 Computation Time: 0.1
# iter: 196 Computation Time: 0.1
# iter: 197 Computation Time: 0.1
# iter: 198 Computation Time: 0.1
# iter: 199 Computation Time: 0.1
# total time spent:  56.19822025299072
# iter: 0 Computation Time: 1
# iter: 1 Computation Time: 1
# iter: 2 Computation Time: 1
# iter: 3 Computation Time: 1
# iter: 4 Computation Time: 1
# iter: 5 Computation Time: 1
# iter: 6 Computation Time: 1
# iter: 7 Computation Time: 1
# iter: 8 Computation Time: 1
# iter: 9 Computation Time: 1
# iter: 10 Computation Time: 1
# iter: 11 Computation Time: 1
# iter: 12 Computation Time: 1
# iter: 13 Computation Time: 1
# iter: 14 Computation Time: 1
# iter: 15 Computation Time: 1
# iter: 16 Computation Time: 1
# iter: 17 Computation Time: 1
# iter: 18 Computation Time: 1
# iter: 19 Computation Time: 1
# iter: 20 Computation Time: 1
# iter: 21 Computation Time: 1
# iter: 22 Computation Time: 1
# iter: 23 Computation Time: 1
# iter: 24 Computation Time: 1
# iter: 25 Computation Time: 1
# iter: 26 Computation Time: 1
# iter: 27 Computation Time: 1
# iter: 28 Computation Time: 1
# iter: 29 Computation Time: 1
# iter: 30 Computation Time: 1
# iter: 31 Computation Time: 1
# iter: 32 Computation Time: 1
# iter: 33 Computation Time: 1
# iter: 34 Computation Time: 1
# iter: 35 Computation Time: 1
# iter: 36 Computation Time: 1
# iter: 37 Computation Time: 1
# iter: 38 Computation Time: 1
# iter: 39 Computation Time: 1
# iter: 40 Computation Time: 1
# iter: 41 Computation Time: 1
# iter: 42 Computation Time: 1
# iter: 43 Computation Time: 1
# iter: 44 Computation Time: 1
# iter: 45 Computation Time: 1
# iter: 46 Computation Time: 1
# iter: 47 Computation Time: 1
# iter: 48 Computation Time: 1
# iter: 49 Computation Time: 1
# iter: 50 Computation Time: 1
# iter: 51 Computation Time: 1
# iter: 52 Computation Time: 1
# iter: 53 Computation Time: 1
# iter: 54 Computation Time: 1
# iter: 55 Computation Time: 1
# iter: 56 Computation Time: 1
# iter: 57 Computation Time: 1
# iter: 58 Computation Time: 1
# iter: 59 Computation Time: 1
# iter: 60 Computation Time: 1
# iter: 61 Computation Time: 1
# iter: 62 Computation Time: 1
# iter: 63 Computation Time: 1
# iter: 64 Computation Time: 1
# iter: 65 Computation Time: 1
# iter: 66 Computation Time: 1
# iter: 67 Computation Time: 1
# iter: 68 Computation Time: 1
# iter: 69 Computation Time: 1
# iter: 70 Computation Time: 1
# iter: 71 Computation Time: 1
# iter: 72 Computation Time: 1
# iter: 73 Computation Time: 1
# iter: 74 Computation Time: 1
# iter: 75 Computation Time: 1
# iter: 76 Computation Time: 1
# iter: 77 Computation Time: 1
# iter: 78 Computation Time: 1
# iter: 79 Computation Time: 1
# iter: 80 Computation Time: 1
# iter: 81 Computation Time: 1
# iter: 82 Computation Time: 1
# iter: 83 Computation Time: 1
# iter: 84 Computation Time: 1
# iter: 85 Computation Time: 1
# iter: 86 Computation Time: 1
# iter: 87 Computation Time: 1
# iter: 88 Computation Time: 1
# iter: 89 Computation Time: 1
# iter: 90 Computation Time: 1
# iter: 91 Computation Time: 1
# iter: 92 Computation Time: 1
# iter: 93 Computation Time: 1
# iter: 94 Computation Time: 1
# iter: 95 Computation Time: 1
# iter: 96 Computation Time: 1
# iter: 97 Computation Time: 1
# iter: 98 Computation Time: 1
# iter: 99 Computation Time: 1
# iter: 100 Computation Time: 1
# iter: 101 Computation Time: 1
# iter: 102 Computation Time: 1
# iter: 103 Computation Time: 1
# iter: 104 Computation Time: 1
# iter: 105 Computation Time: 1
# iter: 106 Computation Time: 1
# iter: 107 Computation Time: 1
# iter: 108 Computation Time: 1
# iter: 109 Computation Time: 1
# iter: 110 Computation Time: 1
# iter: 111 Computation Time: 1
# iter: 112 Computation Time: 1
# iter: 113 Computation Time: 1
# iter: 114 Computation Time: 1
# iter: 115 Computation Time: 1
# iter: 116 Computation Time: 1
# iter: 117 Computation Time: 1
# iter: 118 Computation Time: 1
# iter: 119 Computation Time: 1
# iter: 120 Computation Time: 1
# iter: 121 Computation Time: 1
# iter: 122 Computation Time: 1
# iter: 123 Computation Time: 1
# iter: 124 Computation Time: 1
# iter: 125 Computation Time: 1
# iter: 126 Computation Time: 1
# iter: 127 Computation Time: 1
# iter: 128 Computation Time: 1
# iter: 129 Computation Time: 1
# iter: 130 Computation Time: 1
# iter: 131 Computation Time: 1
# iter: 132 Computation Time: 1
# iter: 133 Computation Time: 1
# iter: 134 Computation Time: 1
# iter: 135 Computation Time: 1
# iter: 136 Computation Time: 1
# iter: 137 Computation Time: 1
# iter: 138 Computation Time: 1
# iter: 139 Computation Time: 1
# iter: 140 Computation Time: 1
# iter: 141 Computation Time: 1
# iter: 142 Computation Time: 1
# iter: 143 Computation Time: 1
# iter: 144 Computation Time: 1
# iter: 145 Computation Time: 1
# iter: 146 Computation Time: 1
# iter: 147 Computation Time: 1
# iter: 148 Computation Time: 1
# iter: 149 Computation Time: 1
# iter: 150 Computation Time: 1
# iter: 151 Computation Time: 1
# iter: 152 Computation Time: 1
# iter: 153 Computation Time: 1
# iter: 154 Computation Time: 1
# iter: 155 Computation Time: 1
# iter: 156 Computation Time: 1
# iter: 157 Computation Time: 1
# iter: 158 Computation Time: 1
# iter: 159 Computation Time: 1
# iter: 160 Computation Time: 1
# iter: 161 Computation Time: 1
# iter: 162 Computation Time: 1
# iter: 163 Computation Time: 1
# iter: 164 Computation Time: 1
# iter: 165 Computation Time: 1
# iter: 166 Computation Time: 1
# iter: 167 Computation Time: 1
# iter: 168 Computation Time: 1
# iter: 169 Computation Time: 1
# iter: 170 Computation Time: 1
# iter: 171 Computation Time: 1
# iter: 172 Computation Time: 1
# iter: 173 Computation Time: 1
# iter: 174 Computation Time: 1
# iter: 175 Computation Time: 1
# iter: 176 Computation Time: 1
# iter: 177 Computation Time: 1
# iter: 178 Computation Time: 1
# iter: 179 Computation Time: 1
# iter: 180 Computation Time: 1
# iter: 181 Computation Time: 1
# iter: 182 Computation Time: 1
# iter: 183 Computation Time: 1
# iter: 184 Computation Time: 1
# iter: 185 Computation Time: 1
# iter: 186 Computation Time: 1
# iter: 187 Computation Time: 1
# iter: 188 Computation Time: 1
# iter: 189 Computation Time: 1
# iter: 190 Computation Time: 1
# iter: 191 Computation Time: 1
# iter: 192 Computation Time: 1
# iter: 193 Computation Time: 1
# iter: 194 Computation Time: 1
# iter: 195 Computation Time: 1
# iter: 196 Computation Time: 1
# iter: 197 Computation Time: 1
# iter: 198 Computation Time: 1
# iter: 199 Computation Time: 1
# total time spent:  416.0056457519531
# iter: 0 Computation Time: 3
# iter: 1 Computation Time: 3
# iter: 2 Computation Time: 3
# iter: 3 Computation Time: 3
# iter: 4 Computation Time: 3
# iter: 5 Computation Time: 3
# iter: 6 Computation Time: 3
# iter: 7 Computation Time: 3
# iter: 8 Computation Time: 3
# iter: 9 Computation Time: 3
# iter: 10 Computation Time: 3
# iter: 11 Computation Time: 3
# iter: 12 Computation Time: 3
# iter: 13 Computation Time: 3
# iter: 14 Computation Time: 3
# iter: 15 Computation Time: 3
# iter: 16 Computation Time: 3
# iter: 17 Computation Time: 3
# iter: 18 Computation Time: 3
# iter: 19 Computation Time: 3
# iter: 20 Computation Time: 3
# iter: 21 Computation Time: 3
# iter: 22 Computation Time: 3
# iter: 23 Computation Time: 3
# iter: 24 Computation Time: 3
# iter: 25 Computation Time: 3
# iter: 26 Computation Time: 3
# iter: 27 Computation Time: 3
# iter: 28 Computation Time: 3
# iter: 29 Computation Time: 3
# iter: 30 Computation Time: 3
# iter: 31 Computation Time: 3
# iter: 32 Computation Time: 3
# iter: 33 Computation Time: 3
# iter: 34 Computation Time: 3
# iter: 35 Computation Time: 3
# iter: 36 Computation Time: 3
# iter: 37 Computation Time: 3
# iter: 38 Computation Time: 3
# iter: 39 Computation Time: 3
# iter: 40 Computation Time: 3
# iter: 41 Computation Time: 3
# iter: 42 Computation Time: 3
# iter: 43 Computation Time: 3
# iter: 44 Computation Time: 3
# iter: 45 Computation Time: 3
# iter: 46 Computation Time: 3
# iter: 47 Computation Time: 3
# iter: 48 Computation Time: 3
# iter: 49 Computation Time: 3
# iter: 50 Computation Time: 3
# iter: 51 Computation Time: 3
# iter: 52 Computation Time: 3
# iter: 53 Computation Time: 3
# iter: 54 Computation Time: 3
# iter: 55 Computation Time: 3
# iter: 56 Computation Time: 3
# iter: 57 Computation Time: 3
# iter: 58 Computation Time: 3
# iter: 59 Computation Time: 3
# iter: 60 Computation Time: 3
# iter: 61 Computation Time: 3
# iter: 62 Computation Time: 3
# iter: 63 Computation Time: 3
# iter: 64 Computation Time: 3
# iter: 65 Computation Time: 3
# iter: 66 Computation Time: 3
# iter: 67 Computation Time: 3
# iter: 68 Computation Time: 3
# iter: 69 Computation Time: 3
# iter: 70 Computation Time: 3
# iter: 71 Computation Time: 3
# iter: 72 Computation Time: 3
# iter: 73 Computation Time: 3
# iter: 74 Computation Time: 3
# iter: 75 Computation Time: 3
# iter: 76 Computation Time: 3
# iter: 77 Computation Time: 3
# iter: 78 Computation Time: 3
# iter: 79 Computation Time: 3
# iter: 80 Computation Time: 3
# iter: 81 Computation Time: 3
# iter: 82 Computation Time: 3
# iter: 83 Computation Time: 3
# iter: 84 Computation Time: 3
# iter: 85 Computation Time: 3
# iter: 86 Computation Time: 3
# iter: 87 Computation Time: 3
# iter: 88 Computation Time: 3
# iter: 89 Computation Time: 3
# iter: 90 Computation Time: 3
# iter: 91 Computation Time: 3
# iter: 92 Computation Time: 3
# iter: 93 Computation Time: 3
# iter: 94 Computation Time: 3
# iter: 95 Computation Time: 3
# iter: 96 Computation Time: 3
# iter: 97 Computation Time: 3
# iter: 98 Computation Time: 3
# iter: 99 Computation Time: 3
# iter: 100 Computation Time: 3
# iter: 101 Computation Time: 3
# iter: 102 Computation Time: 3
# iter: 103 Computation Time: 3
# iter: 104 Computation Time: 3
# iter: 105 Computation Time: 3
# iter: 106 Computation Time: 3
# iter: 107 Computation Time: 3
# iter: 108 Computation Time: 3
# iter: 109 Computation Time: 3
# iter: 110 Computation Time: 3
# iter: 111 Computation Time: 3
# iter: 112 Computation Time: 3
# iter: 113 Computation Time: 3
# iter: 114 Computation Time: 3
# iter: 115 Computation Time: 3
# iter: 116 Computation Time: 3
# iter: 117 Computation Time: 3
# iter: 118 Computation Time: 3
# iter: 119 Computation Time: 3
# iter: 120 Computation Time: 3
# iter: 121 Computation Time: 3
# iter: 122 Computation Time: 3
# iter: 123 Computation Time: 3
# iter: 124 Computation Time: 3
# iter: 125 Computation Time: 3
# iter: 126 Computation Time: 3
# iter: 127 Computation Time: 3
# iter: 128 Computation Time: 3
# iter: 129 Computation Time: 3
# iter: 130 Computation Time: 3
# iter: 131 Computation Time: 3
# iter: 132 Computation Time: 3
# iter: 133 Computation Time: 3
# iter: 134 Computation Time: 3
# iter: 135 Computation Time: 3
# iter: 136 Computation Time: 3
# iter: 137 Computation Time: 3
# iter: 138 Computation Time: 3
# iter: 139 Computation Time: 3
# iter: 140 Computation Time: 3
# iter: 141 Computation Time: 3
# iter: 142 Computation Time: 3
# iter: 143 Computation Time: 3
# iter: 144 Computation Time: 3
# iter: 145 Computation Time: 3
# iter: 146 Computation Time: 3
# iter: 147 Computation Time: 3
# iter: 148 Computation Time: 3
# iter: 149 Computation Time: 3
# iter: 150 Computation Time: 3
# iter: 151 Computation Time: 3
# iter: 152 Computation Time: 3
# iter: 153 Computation Time: 3
# iter: 154 Computation Time: 3
# iter: 155 Computation Time: 3
# iter: 156 Computation Time: 3
# iter: 157 Computation Time: 3
# iter: 158 Computation Time: 3
# iter: 159 Computation Time: 3
# iter: 160 Computation Time: 3
# iter: 161 Computation Time: 3
# iter: 162 Computation Time: 3
# iter: 163 Computation Time: 3
# iter: 164 Computation Time: 3
# iter: 165 Computation Time: 3
# iter: 166 Computation Time: 3
# iter: 167 Computation Time: 3
# iter: 168 Computation Time: 3
# iter: 169 Computation Time: 3
# iter: 170 Computation Time: 3
# iter: 171 Computation Time: 3
# iter: 172 Computation Time: 3
# iter: 173 Computation Time: 3
# iter: 174 Computation Time: 3
# iter: 175 Computation Time: 3
# iter: 176 Computation Time: 3
# iter: 177 Computation Time: 3
# iter: 178 Computation Time: 3
# iter: 179 Computation Time: 3
# iter: 180 Computation Time: 3
# iter: 181 Computation Time: 3
# iter: 182 Computation Time: 3
# iter: 183 Computation Time: 3
# iter: 184 Computation Time: 3
# iter: 185 Computation Time: 3
# iter: 186 Computation Time: 3
# iter: 187 Computation Time: 3
# iter: 188 Computation Time: 3
# iter: 189 Computation Time: 3
# iter: 190 Computation Time: 3
# iter: 191 Computation Time: 3
# iter: 192 Computation Time: 3
# iter: 193 Computation Time: 3
# iter: 194 Computation Time: 3
# iter: 195 Computation Time: 3
# iter: 196 Computation Time: 3
# iter: 197 Computation Time: 3
# iter: 198 Computation Time: 3
# iter: 199 Computation Time: 3
# total time spent:  1189.8836658000946
# iter: 0 Computation Time: 5
# iter: 1 Computation Time: 5
# iter: 2 Computation Time: 5
# iter: 3 Computation Time: 5
# iter: 4 Computation Time: 5
# iter: 5 Computation Time: 5
# iter: 6 Computation Time: 5
# iter: 7 Computation Time: 5
# iter: 8 Computation Time: 5
# iter: 9 Computation Time: 5
# iter: 10 Computation Time: 5
# iter: 11 Computation Time: 5
# iter: 12 Computation Time: 5
# iter: 13 Computation Time: 5
# iter: 14 Computation Time: 5
# iter: 15 Computation Time: 5
# iter: 16 Computation Time: 5
# iter: 17 Computation Time: 5
# iter: 18 Computation Time: 5
# iter: 19 Computation Time: 5
# iter: 20 Computation Time: 5
# iter: 21 Computation Time: 5
# iter: 22 Computation Time: 5
# iter: 23 Computation Time: 5
# iter: 24 Computation Time: 5
# iter: 25 Computation Time: 5
# iter: 26 Computation Time: 5
# iter: 27 Computation Time: 5
# iter: 28 Computation Time: 5
# iter: 29 Computation Time: 5
# iter: 30 Computation Time: 5
# iter: 31 Computation Time: 5
# iter: 32 Computation Time: 5
# iter: 33 Computation Time: 5
# iter: 34 Computation Time: 5
# iter: 35 Computation Time: 5
# iter: 36 Computation Time: 5
# iter: 37 Computation Time: 5
# iter: 38 Computation Time: 5
# iter: 39 Computation Time: 5
# iter: 40 Computation Time: 5
# iter: 41 Computation Time: 5
# iter: 42 Computation Time: 5
# iter: 43 Computation Time: 5
# iter: 44 Computation Time: 5
# iter: 45 Computation Time: 5
# iter: 46 Computation Time: 5
# iter: 47 Computation Time: 5
# iter: 48 Computation Time: 5
# iter: 49 Computation Time: 5
# iter: 50 Computation Time: 5
# iter: 51 Computation Time: 5
# iter: 52 Computation Time: 5
# iter: 53 Computation Time: 5
# iter: 54 Computation Time: 5
# iter: 55 Computation Time: 5
# iter: 56 Computation Time: 5
# iter: 57 Computation Time: 5
# iter: 58 Computation Time: 5
# iter: 59 Computation Time: 5
# iter: 60 Computation Time: 5
# iter: 61 Computation Time: 5
# iter: 62 Computation Time: 5
# iter: 63 Computation Time: 5
# iter: 64 Computation Time: 5
# iter: 65 Computation Time: 5
# iter: 66 Computation Time: 5
# iter: 67 Computation Time: 5
# iter: 68 Computation Time: 5
# iter: 69 Computation Time: 5
# iter: 70 Computation Time: 5
# iter: 71 Computation Time: 5
# iter: 72 Computation Time: 5
# iter: 73 Computation Time: 5
# iter: 74 Computation Time: 5
# iter: 75 Computation Time: 5
# iter: 76 Computation Time: 5
# iter: 77 Computation Time: 5
# iter: 78 Computation Time: 5
# iter: 79 Computation Time: 5
# iter: 80 Computation Time: 5
# iter: 81 Computation Time: 5
# iter: 82 Computation Time: 5
# iter: 83 Computation Time: 5
# iter: 84 Computation Time: 5
# iter: 85 Computation Time: 5
# iter: 86 Computation Time: 5
# iter: 87 Computation Time: 5
# iter: 88 Computation Time: 5
# iter: 89 Computation Time: 5
# iter: 90 Computation Time: 5
# iter: 91 Computation Time: 5
# iter: 92 Computation Time: 5
# iter: 93 Computation Time: 5
# iter: 94 Computation Time: 5
# iter: 95 Computation Time: 5
# iter: 96 Computation Time: 5
# iter: 97 Computation Time: 5
# iter: 98 Computation Time: 5
# iter: 99 Computation Time: 5
# iter: 100 Computation Time: 5
# iter: 101 Computation Time: 5
# iter: 102 Computation Time: 5
# iter: 103 Computation Time: 5
# iter: 104 Computation Time: 5
# iter: 105 Computation Time: 5
# iter: 106 Computation Time: 5
# iter: 107 Computation Time: 5
# iter: 108 Computation Time: 5
# iter: 109 Computation Time: 5
# iter: 110 Computation Time: 5
# iter: 111 Computation Time: 5
# iter: 112 Computation Time: 5
# iter: 113 Computation Time: 5
# iter: 114 Computation Time: 5
# iter: 115 Computation Time: 5
# iter: 116 Computation Time: 5
# iter: 117 Computation Time: 5
# iter: 118 Computation Time: 5
# iter: 119 Computation Time: 5
# iter: 120 Computation Time: 5
# iter: 121 Computation Time: 5
# iter: 122 Computation Time: 5
# iter: 123 Computation Time: 5
# iter: 124 Computation Time: 5
# iter: 125 Computation Time: 5
# iter: 126 Computation Time: 5
# iter: 127 Computation Time: 5
# iter: 128 Computation Time: 5
# iter: 129 Computation Time: 5
# iter: 130 Computation Time: 5
# iter: 131 Computation Time: 5
# iter: 132 Computation Time: 5
# iter: 133 Computation Time: 5
# iter: 134 Computation Time: 5
# iter: 135 Computation Time: 5
# iter: 136 Computation Time: 5
# iter: 137 Computation Time: 5
# iter: 138 Computation Time: 5
# iter: 139 Computation Time: 5
# iter: 140 Computation Time: 5
# iter: 141 Computation Time: 5
# iter: 142 Computation Time: 5
# iter: 143 Computation Time: 5
# iter: 144 Computation Time: 5
# iter: 145 Computation Time: 5
# iter: 146 Computation Time: 5
# iter: 147 Computation Time: 5
# iter: 148 Computation Time: 5
# iter: 149 Computation Time: 5
# iter: 150 Computation Time: 5
# iter: 151 Computation Time: 5
# iter: 152 Computation Time: 5
# iter: 153 Computation Time: 5
# iter: 154 Computation Time: 5
# iter: 155 Computation Time: 5
# iter: 156 Computation Time: 5
# iter: 157 Computation Time: 5
# iter: 158 Computation Time: 5
# iter: 159 Computation Time: 5
# iter: 160 Computation Time: 5
# iter: 161 Computation Time: 5
# iter: 162 Computation Time: 5
# iter: 163 Computation Time: 5
# iter: 164 Computation Time: 5
# iter: 165 Computation Time: 5
# iter: 166 Computation Time: 5
# iter: 167 Computation Time: 5
# iter: 168 Computation Time: 5
# iter: 169 Computation Time: 5
# iter: 170 Computation Time: 5
# iter: 171 Computation Time: 5
# iter: 172 Computation Time: 5
# iter: 173 Computation Time: 5
# iter: 174 Computation Time: 5
# iter: 175 Computation Time: 5
# iter: 176 Computation Time: 5
# iter: 177 Computation Time: 5
# iter: 178 Computation Time: 5
# iter: 179 Computation Time: 5
# iter: 180 Computation Time: 5
# iter: 181 Computation Time: 5
# iter: 182 Computation Time: 5
# iter: 183 Computation Time: 5
# iter: 184 Computation Time: 5
# iter: 185 Computation Time: 5
# iter: 186 Computation Time: 5
# iter: 187 Computation Time: 5
# iter: 188 Computation Time: 5
# iter: 189 Computation Time: 5
# iter: 190 Computation Time: 5
# iter: 191 Computation Time: 5
# iter: 192 Computation Time: 5
# iter: 193 Computation Time: 5
# iter: 194 Computation Time: 5
# iter: 195 Computation Time: 5
# iter: 196 Computation Time: 5
# iter: 197 Computation Time: 5
# iter: 198 Computation Time: 5
# iter: 199 Computation Time: 5
# total time spent:  1902.619485616684
# iter: 0 Computation Time: 7
# iter: 1 Computation Time: 7
# iter: 2 Computation Time: 7
# iter: 3 Computation Time: 7
# iter: 4 Computation Time: 7
# iter: 5 Computation Time: 7
# iter: 6 Computation Time: 7
# iter: 7 Computation Time: 7
# iter: 8 Computation Time: 7
# iter: 9 Computation Time: 7
# iter: 10 Computation Time: 7
# iter: 11 Computation Time: 7
# iter: 12 Computation Time: 7
# iter: 13 Computation Time: 7
# iter: 14 Computation Time: 7
# iter: 15 Computation Time: 7
# iter: 16 Computation Time: 7
# iter: 17 Computation Time: 7
# iter: 18 Computation Time: 7
# iter: 19 Computation Time: 7
# iter: 20 Computation Time: 7
# iter: 21 Computation Time: 7
# iter: 22 Computation Time: 7
# iter: 23 Computation Time: 7
# iter: 24 Computation Time: 7
# iter: 25 Computation Time: 7
# iter: 26 Computation Time: 7
# iter: 27 Computation Time: 7
# iter: 28 Computation Time: 7
# iter: 29 Computation Time: 7
# iter: 30 Computation Time: 7
# iter: 31 Computation Time: 7
# iter: 32 Computation Time: 7
# iter: 33 Computation Time: 7
# iter: 34 Computation Time: 7
# iter: 35 Computation Time: 7
# iter: 36 Computation Time: 7
# iter: 37 Computation Time: 7
# iter: 38 Computation Time: 7
# iter: 39 Computation Time: 7
# iter: 40 Computation Time: 7
# iter: 41 Computation Time: 7
# iter: 42 Computation Time: 7
# iter: 43 Computation Time: 7
# iter: 44 Computation Time: 7
# iter: 45 Computation Time: 7
# iter: 46 Computation Time: 7
# iter: 47 Computation Time: 7
# iter: 48 Computation Time: 7
# iter: 49 Computation Time: 7
# iter: 50 Computation Time: 7
# iter: 51 Computation Time: 7
# iter: 52 Computation Time: 7
# iter: 53 Computation Time: 7
# iter: 54 Computation Time: 7
# iter: 55 Computation Time: 7
# iter: 56 Computation Time: 7
# iter: 57 Computation Time: 7
# iter: 58 Computation Time: 7
# iter: 59 Computation Time: 7
# iter: 60 Computation Time: 7
# iter: 61 Computation Time: 7
# iter: 62 Computation Time: 7
# iter: 63 Computation Time: 7
# iter: 64 Computation Time: 7
# iter: 65 Computation Time: 7
# iter: 66 Computation Time: 7
# iter: 67 Computation Time: 7
# iter: 68 Computation Time: 7
# iter: 69 Computation Time: 7
# iter: 70 Computation Time: 7
# iter: 71 Computation Time: 7
# iter: 72 Computation Time: 7
# iter: 73 Computation Time: 7
# iter: 74 Computation Time: 7
# iter: 75 Computation Time: 7
# iter: 76 Computation Time: 7
# iter: 77 Computation Time: 7
# iter: 78 Computation Time: 7
# iter: 79 Computation Time: 7
# iter: 80 Computation Time: 7
# iter: 81 Computation Time: 7
# iter: 82 Computation Time: 7
# iter: 83 Computation Time: 7
# iter: 84 Computation Time: 7
# iter: 85 Computation Time: 7
# iter: 86 Computation Time: 7
# iter: 87 Computation Time: 7
# iter: 88 Computation Time: 7
# iter: 89 Computation Time: 7
# iter: 90 Computation Time: 7
# iter: 91 Computation Time: 7
# iter: 92 Computation Time: 7
# iter: 93 Computation Time: 7
# iter: 94 Computation Time: 7
# iter: 95 Computation Time: 7
# iter: 96 Computation Time: 7
# iter: 97 Computation Time: 7
# iter: 98 Computation Time: 7
# iter: 99 Computation Time: 7
# iter: 100 Computation Time: 7
# iter: 101 Computation Time: 7
# iter: 102 Computation Time: 7
# iter: 103 Computation Time: 7
# iter: 104 Computation Time: 7
# iter: 105 Computation Time: 7
# iter: 106 Computation Time: 7
# iter: 107 Computation Time: 7
# iter: 108 Computation Time: 7
# iter: 109 Computation Time: 7
# iter: 110 Computation Time: 7
# iter: 111 Computation Time: 7
# iter: 112 Computation Time: 7
# iter: 113 Computation Time: 7
# iter: 114 Computation Time: 7
# iter: 115 Computation Time: 7
# iter: 116 Computation Time: 7
# iter: 117 Computation Time: 7
# iter: 118 Computation Time: 7
# iter: 119 Computation Time: 7
# iter: 120 Computation Time: 7
# iter: 121 Computation Time: 7
# iter: 122 Computation Time: 7
# iter: 123 Computation Time: 7
# iter: 124 Computation Time: 7
# iter: 125 Computation Time: 7
# iter: 126 Computation Time: 7
# iter: 127 Computation Time: 7
# iter: 128 Computation Time: 7
# iter: 129 Computation Time: 7
# iter: 130 Computation Time: 7
# iter: 131 Computation Time: 7
# iter: 132 Computation Time: 7
# iter: 133 Computation Time: 7
# iter: 134 Computation Time: 7
# iter: 135 Computation Time: 7
# iter: 136 Computation Time: 7
# iter: 137 Computation Time: 7
# iter: 138 Computation Time: 7
# iter: 139 Computation Time: 7
# iter: 140 Computation Time: 7
# iter: 141 Computation Time: 7
# iter: 142 Computation Time: 7
# iter: 143 Computation Time: 7
# iter: 144 Computation Time: 7
# iter: 145 Computation Time: 7
# iter: 146 Computation Time: 7
# iter: 147 Computation Time: 7
# iter: 148 Computation Time: 7
# iter: 149 Computation Time: 7
# iter: 150 Computation Time: 7
# iter: 151 Computation Time: 7
# iter: 152 Computation Time: 7
# iter: 153 Computation Time: 7
# iter: 154 Computation Time: 7
# iter: 155 Computation Time: 7
# iter: 156 Computation Time: 7
# iter: 157 Computation Time: 7
# iter: 158 Computation Time: 7
# iter: 159 Computation Time: 7
# iter: 160 Computation Time: 7
# iter: 161 Computation Time: 7
# iter: 162 Computation Time: 7
# iter: 163 Computation Time: 7
# iter: 164 Computation Time: 7
# iter: 165 Computation Time: 7
# iter: 166 Computation Time: 7
# iter: 167 Computation Time: 7
# iter: 168 Computation Time: 7
# iter: 169 Computation Time: 7
# iter: 170 Computation Time: 7
# iter: 171 Computation Time: 7
# iter: 172 Computation Time: 7
# iter: 173 Computation Time: 7
# iter: 174 Computation Time: 7
# iter: 175 Computation Time: 7
# iter: 176 Computation Time: 7
# iter: 177 Computation Time: 7
# iter: 178 Computation Time: 7
# iter: 179 Computation Time: 7
# iter: 180 Computation Time: 7
# iter: 181 Computation Time: 7
# iter: 182 Computation Time: 7
# iter: 183 Computation Time: 7
# iter: 184 Computation Time: 7
# iter: 185 Computation Time: 7
# iter: 186 Computation Time: 7
# iter: 187 Computation Time: 7
# iter: 188 Computation Time: 7
# iter: 189 Computation Time: 7
# iter: 190 Computation Time: 7
# iter: 191 Computation Time: 7
# iter: 192 Computation Time: 7
# iter: 193 Computation Time: 7
# iter: 194 Computation Time: 7
# iter: 195 Computation Time: 7
# iter: 196 Computation Time: 7
# iter: 197 Computation Time: 7
# iter: 198 Computation Time: 7
# iter: 199 Computation Time: 7
# total time spent:  2478.4139442443848
# iter: 0 Computation Time: 9
# iter: 1 Computation Time: 9
# iter: 2 Computation Time: 9
# iter: 3 Computation Time: 9
# iter: 4 Computation Time: 9
# iter: 5 Computation Time: 9
# iter: 6 Computation Time: 9
# iter: 7 Computation Time: 9
# iter: 8 Computation Time: 9
# iter: 9 Computation Time: 9
# iter: 10 Computation Time: 9
# iter: 11 Computation Time: 9
# iter: 12 Computation Time: 9
# iter: 13 Computation Time: 9
# iter: 14 Computation Time: 9
# iter: 15 Computation Time: 9
# iter: 16 Computation Time: 9
# iter: 17 Computation Time: 9
# iter: 18 Computation Time: 9
# iter: 19 Computation Time: 9
# iter: 20 Computation Time: 9
# iter: 21 Computation Time: 9
# iter: 22 Computation Time: 9
# iter: 23 Computation Time: 9
# iter: 24 Computation Time: 9
# iter: 25 Computation Time: 9
# iter: 26 Computation Time: 9
# iter: 27 Computation Time: 9
# iter: 28 Computation Time: 9
# iter: 29 Computation Time: 9
# iter: 30 Computation Time: 9
# iter: 31 Computation Time: 9
# iter: 32 Computation Time: 9
# iter: 33 Computation Time: 9
# iter: 34 Computation Time: 9
# iter: 35 Computation Time: 9
# iter: 36 Computation Time: 9
# iter: 37 Computation Time: 9
# iter: 38 Computation Time: 9
# iter: 39 Computation Time: 9
# iter: 40 Computation Time: 9
# iter: 41 Computation Time: 9
# iter: 42 Computation Time: 9
# iter: 43 Computation Time: 9
# iter: 44 Computation Time: 9
# iter: 45 Computation Time: 9
# iter: 46 Computation Time: 9
# iter: 47 Computation Time: 9
# iter: 48 Computation Time: 9
# iter: 49 Computation Time: 9
# iter: 50 Computation Time: 9
# iter: 51 Computation Time: 9
# iter: 52 Computation Time: 9
# iter: 53 Computation Time: 9
# iter: 54 Computation Time: 9
# iter: 55 Computation Time: 9
# iter: 56 Computation Time: 9
# iter: 57 Computation Time: 9
# iter: 58 Computation Time: 9
# iter: 59 Computation Time: 9
# iter: 60 Computation Time: 9
# iter: 61 Computation Time: 9
# iter: 62 Computation Time: 9
# iter: 63 Computation Time: 9
# iter: 64 Computation Time: 9
# iter: 65 Computation Time: 9
# iter: 66 Computation Time: 9
# iter: 67 Computation Time: 9
# iter: 68 Computation Time: 9
# iter: 69 Computation Time: 9
# iter: 70 Computation Time: 9
# iter: 71 Computation Time: 9
# iter: 72 Computation Time: 9
# iter: 73 Computation Time: 9
# iter: 74 Computation Time: 9
# iter: 75 Computation Time: 9
# iter: 76 Computation Time: 9
# iter: 77 Computation Time: 9
# iter: 78 Computation Time: 9
# iter: 79 Computation Time: 9
# iter: 80 Computation Time: 9
# iter: 81 Computation Time: 9
# iter: 82 Computation Time: 9
# iter: 83 Computation Time: 9
# iter: 84 Computation Time: 9
# iter: 85 Computation Time: 9
# iter: 86 Computation Time: 9
# iter: 87 Computation Time: 9
# iter: 88 Computation Time: 9
# iter: 89 Computation Time: 9
# iter: 90 Computation Time: 9
# iter: 91 Computation Time: 9
# iter: 92 Computation Time: 9
# iter: 93 Computation Time: 9
# iter: 94 Computation Time: 9
# iter: 95 Computation Time: 9
# iter: 96 Computation Time: 9
# iter: 97 Computation Time: 9
# iter: 98 Computation Time: 9
# iter: 99 Computation Time: 9
# iter: 100 Computation Time: 9
# iter: 101 Computation Time: 9
# iter: 102 Computation Time: 9
# iter: 103 Computation Time: 9
# iter: 104 Computation Time: 9
# iter: 105 Computation Time: 9
# iter: 106 Computation Time: 9
# iter: 107 Computation Time: 9
# iter: 108 Computation Time: 9
# iter: 109 Computation Time: 9
# iter: 110 Computation Time: 9
# iter: 111 Computation Time: 9
# iter: 112 Computation Time: 9
# iter: 113 Computation Time: 9
# iter: 114 Computation Time: 9
# iter: 115 Computation Time: 9
# iter: 116 Computation Time: 9
# iter: 117 Computation Time: 9
# iter: 118 Computation Time: 9
# iter: 119 Computation Time: 9
# iter: 120 Computation Time: 9
# iter: 121 Computation Time: 9
# iter: 122 Computation Time: 9
# iter: 123 Computation Time: 9
# iter: 124 Computation Time: 9
# iter: 125 Computation Time: 9
# iter: 126 Computation Time: 9
# iter: 127 Computation Time: 9
# iter: 128 Computation Time: 9
# iter: 129 Computation Time: 9
# iter: 130 Computation Time: 9
# iter: 131 Computation Time: 9
# iter: 132 Computation Time: 9
# iter: 133 Computation Time: 9
# iter: 134 Computation Time: 9
# iter: 135 Computation Time: 9
# iter: 136 Computation Time: 9
# iter: 137 Computation Time: 9
# iter: 138 Computation Time: 9
# iter: 139 Computation Time: 9
# iter: 140 Computation Time: 9
# iter: 141 Computation Time: 9
# iter: 142 Computation Time: 9
# iter: 143 Computation Time: 9
# iter: 144 Computation Time: 9
# iter: 145 Computation Time: 9
# iter: 146 Computation Time: 9
# iter: 147 Computation Time: 9
# iter: 148 Computation Time: 9
# iter: 149 Computation Time: 9
# iter: 150 Computation Time: 9
# iter: 151 Computation Time: 9
# iter: 152 Computation Time: 9
# iter: 153 Computation Time: 9
# iter: 154 Computation Time: 9
# iter: 155 Computation Time: 9
# iter: 156 Computation Time: 9
# iter: 157 Computation Time: 9
# iter: 158 Computation Time: 9
# iter: 159 Computation Time: 9
# iter: 160 Computation Time: 9
# iter: 161 Computation Time: 9
# iter: 162 Computation Time: 9
# iter: 163 Computation Time: 9
# iter: 164 Computation Time: 9
# iter: 165 Computation Time: 9
# iter: 166 Computation Time: 9
# iter: 167 Computation Time: 9
# iter: 168 Computation Time: 9
# iter: 169 Computation Time: 9
# iter: 170 Computation Time: 9
# iter: 171 Computation Time: 9
# iter: 172 Computation Time: 9
# iter: 173 Computation Time: 9
# iter: 174 Computation Time: 9
# iter: 175 Computation Time: 9
# iter: 176 Computation Time: 9
# iter: 177 Computation Time: 9
# iter: 178 Computation Time: 9
# iter: 179 Computation Time: 9
# iter: 180 Computation Time: 9
# iter: 181 Computation Time: 9
# iter: 182 Computation Time: 9
# iter: 183 Computation Time: 9
# iter: 184 Computation Time: 9
# iter: 185 Computation Time: 9
# iter: 186 Computation Time: 9
# iter: 187 Computation Time: 9
# iter: 188 Computation Time: 9
# iter: 189 Computation Time: 9
# iter: 190 Computation Time: 9
# iter: 191 Computation Time: 9
# iter: 192 Computation Time: 9
# iter: 193 Computation Time: 9
# iter: 194 Computation Time: 9
# iter: 195 Computation Time: 9
# iter: 196 Computation Time: 9
# iter: 197 Computation Time: 9
# iter: 198 Computation Time: 9
# iter: 199 Computation Time: 9
# total time spent:  2974.7668533325195
# iter: 0 Computation Time: 10
# iter: 1 Computation Time: 10
# iter: 2 Computation Time: 10
# iter: 3 Computation Time: 10
# iter: 4 Computation Time: 10
# iter: 5 Computation Time: 10
# iter: 6 Computation Time: 10
# iter: 7 Computation Time: 10
# iter: 8 Computation Time: 10
# iter: 9 Computation Time: 10
# iter: 10 Computation Time: 10
# iter: 11 Computation Time: 10
# iter: 12 Computation Time: 10
# iter: 13 Computation Time: 10
# iter: 14 Computation Time: 10
# iter: 15 Computation Time: 10
# iter: 16 Computation Time: 10
# iter: 17 Computation Time: 10
# iter: 18 Computation Time: 10
# iter: 19 Computation Time: 10
# iter: 20 Computation Time: 10
# iter: 21 Computation Time: 10
# iter: 22 Computation Time: 10
# iter: 23 Computation Time: 10
# iter: 24 Computation Time: 10
# iter: 25 Computation Time: 10
# iter: 26 Computation Time: 10
# iter: 27 Computation Time: 10
# iter: 28 Computation Time: 10
# iter: 29 Computation Time: 10
# iter: 30 Computation Time: 10
# iter: 31 Computation Time: 10
# iter: 32 Computation Time: 10
# iter: 33 Computation Time: 10
# iter: 34 Computation Time: 10
# iter: 35 Computation Time: 10
# iter: 36 Computation Time: 10
# iter: 37 Computation Time: 10
# iter: 38 Computation Time: 10
# iter: 39 Computation Time: 10
# iter: 40 Computation Time: 10
# iter: 41 Computation Time: 10
# iter: 42 Computation Time: 10
# iter: 43 Computation Time: 10
# iter: 44 Computation Time: 10
# iter: 45 Computation Time: 10
# iter: 46 Computation Time: 10
# iter: 47 Computation Time: 10
# iter: 48 Computation Time: 10
# iter: 49 Computation Time: 10
# iter: 50 Computation Time: 10
# iter: 51 Computation Time: 10
# iter: 52 Computation Time: 10
# iter: 53 Computation Time: 10
# iter: 54 Computation Time: 10
# iter: 55 Computation Time: 10
# iter: 56 Computation Time: 10
# iter: 57 Computation Time: 10
# iter: 58 Computation Time: 10
# iter: 59 Computation Time: 10
# iter: 60 Computation Time: 10
# iter: 61 Computation Time: 10
# iter: 62 Computation Time: 10
# iter: 63 Computation Time: 10
# iter: 64 Computation Time: 10
# iter: 65 Computation Time: 10
# iter: 66 Computation Time: 10
# iter: 67 Computation Time: 10
# iter: 68 Computation Time: 10
# iter: 69 Computation Time: 10
# iter: 70 Computation Time: 10
# iter: 71 Computation Time: 10
# iter: 72 Computation Time: 10
# iter: 73 Computation Time: 10
# iter: 74 Computation Time: 10
# iter: 75 Computation Time: 10
# iter: 76 Computation Time: 10
# iter: 77 Computation Time: 10
# iter: 78 Computation Time: 10
# iter: 79 Computation Time: 10
# iter: 80 Computation Time: 10
# iter: 81 Computation Time: 10
# iter: 82 Computation Time: 10
# iter: 83 Computation Time: 10
# iter: 84 Computation Time: 10
# iter: 85 Computation Time: 10
# iter: 86 Computation Time: 10
# iter: 87 Computation Time: 10
# iter: 88 Computation Time: 10
# iter: 89 Computation Time: 10
# iter: 90 Computation Time: 10
# iter: 91 Computation Time: 10
# iter: 92 Computation Time: 10
# iter: 93 Computation Time: 10
# iter: 94 Computation Time: 10
# iter: 95 Computation Time: 10
# iter: 96 Computation Time: 10
# iter: 97 Computation Time: 10
# iter: 98 Computation Time: 10
# iter: 99 Computation Time: 10
# iter: 100 Computation Time: 10
# iter: 101 Computation Time: 10
# iter: 102 Computation Time: 10
# iter: 103 Computation Time: 10
# iter: 104 Computation Time: 10
# iter: 105 Computation Time: 10
# iter: 106 Computation Time: 10
# iter: 107 Computation Time: 10
# iter: 108 Computation Time: 10
# iter: 109 Computation Time: 10
# iter: 110 Computation Time: 10
# iter: 111 Computation Time: 10
# iter: 112 Computation Time: 10
# iter: 113 Computation Time: 10
# iter: 114 Computation Time: 10
# iter: 115 Computation Time: 10
# iter: 116 Computation Time: 10
# iter: 117 Computation Time: 10
# iter: 118 Computation Time: 10
# iter: 119 Computation Time: 10
# iter: 120 Computation Time: 10
# iter: 121 Computation Time: 10
# iter: 122 Computation Time: 10
# iter: 123 Computation Time: 10
# iter: 124 Computation Time: 10
# iter: 125 Computation Time: 10
# iter: 126 Computation Time: 10
# iter: 127 Computation Time: 10
# iter: 128 Computation Time: 10
# iter: 129 Computation Time: 10
# iter: 130 Computation Time: 10
# iter: 131 Computation Time: 10
# iter: 132 Computation Time: 10
# iter: 133 Computation Time: 10
# iter: 134 Computation Time: 10
# iter: 135 Computation Time: 10
# iter: 136 Computation Time: 10
# iter: 137 Computation Time: 10
# iter: 138 Computation Time: 10
# iter: 139 Computation Time: 10
# iter: 140 Computation Time: 10
# iter: 141 Computation Time: 10
# iter: 142 Computation Time: 10
# iter: 143 Computation Time: 10
# iter: 144 Computation Time: 10
# iter: 145 Computation Time: 10
# iter: 146 Computation Time: 10
# iter: 147 Computation Time: 10
# iter: 148 Computation Time: 10
# iter: 149 Computation Time: 10
# iter: 150 Computation Time: 10
# iter: 151 Computation Time: 10
# iter: 152 Computation Time: 10
# iter: 153 Computation Time: 10
# iter: 154 Computation Time: 10
# iter: 155 Computation Time: 10
# iter: 156 Computation Time: 10
# iter: 157 Computation Time: 10
# iter: 158 Computation Time: 10
# iter: 159 Computation Time: 10
# iter: 160 Computation Time: 10
# iter: 161 Computation Time: 10
# iter: 162 Computation Time: 10
# iter: 163 Computation Time: 10
# iter: 164 Computation Time: 10
# iter: 165 Computation Time: 10
# iter: 166 Computation Time: 10
# iter: 167 Computation Time: 10
# iter: 168 Computation Time: 10
# iter: 169 Computation Time: 10
# iter: 170 Computation Time: 10
# iter: 171 Computation Time: 10
# iter: 172 Computation Time: 10
# iter: 173 Computation Time: 10
# iter: 174 Computation Time: 10
# iter: 175 Computation Time: 10
# iter: 176 Computation Time: 10
# iter: 177 Computation Time: 10
# iter: 178 Computation Time: 10
# iter: 179 Computation Time: 10
# iter: 180 Computation Time: 10
# iter: 181 Computation Time: 10
# iter: 182 Computation Time: 10
# iter: 183 Computation Time: 10
# iter: 184 Computation Time: 10
# iter: 185 Computation Time: 10
# iter: 186 Computation Time: 10
# iter: 187 Computation Time: 10
# iter: 188 Computation Time: 10
# iter: 189 Computation Time: 10
# iter: 190 Computation Time: 10
# iter: 191 Computation Time: 10
# iter: 192 Computation Time: 10
# iter: 193 Computation Time: 10
# iter: 194 Computation Time: 10
# iter: 195 Computation Time: 10
# iter: 196 Computation Time: 10
# iter: 197 Computation Time: 10
# iter: 198 Computation Time: 10
# iter: 199 Computation Time: 10
# total time spent:  3260.289006948471
# iter: 0 Computation Time: 15
# iter: 1 Computation Time: 15
# iter: 2 Computation Time: 15
# iter: 3 Computation Time: 15
# iter: 4 Computation Time: 15
# iter: 5 Computation Time: 15
# iter: 6 Computation Time: 15
# iter: 7 Computation Time: 15
# iter: 8 Computation Time: 15
# iter: 9 Computation Time: 15
# iter: 10 Computation Time: 15
# iter: 11 Computation Time: 15
# iter: 12 Computation Time: 15
# iter: 13 Computation Time: 15
# iter: 14 Computation Time: 15
# iter: 15 Computation Time: 15
# iter: 16 Computation Time: 15
# iter: 17 Computation Time: 15
# iter: 18 Computation Time: 15
# iter: 19 Computation Time: 15
# iter: 20 Computation Time: 15
# iter: 21 Computation Time: 15
# iter: 22 Computation Time: 15
# iter: 23 Computation Time: 15
# iter: 24 Computation Time: 15
# iter: 25 Computation Time: 15
# iter: 26 Computation Time: 15
# iter: 27 Computation Time: 15
# iter: 28 Computation Time: 15
# iter: 29 Computation Time: 15
# iter: 30 Computation Time: 15
# iter: 31 Computation Time: 15
# iter: 32 Computation Time: 15
# iter: 33 Computation Time: 15
# iter: 34 Computation Time: 15
# iter: 35 Computation Time: 15
# iter: 36 Computation Time: 15
# iter: 37 Computation Time: 15
# iter: 38 Computation Time: 15
# iter: 39 Computation Time: 15
# iter: 40 Computation Time: 15
# iter: 41 Computation Time: 15
# iter: 42 Computation Time: 15
# iter: 43 Computation Time: 15
# iter: 44 Computation Time: 15
# iter: 45 Computation Time: 15
# iter: 46 Computation Time: 15
# iter: 47 Computation Time: 15
# iter: 48 Computation Time: 15
# iter: 49 Computation Time: 15
# iter: 50 Computation Time: 15
# iter: 51 Computation Time: 15
# iter: 52 Computation Time: 15
# iter: 53 Computation Time: 15
# iter: 54 Computation Time: 15
# iter: 55 Computation Time: 15
# iter: 56 Computation Time: 15
# iter: 57 Computation Time: 15
# iter: 58 Computation Time: 15
# iter: 59 Computation Time: 15
# iter: 60 Computation Time: 15
# iter: 61 Computation Time: 15
# iter: 62 Computation Time: 15
# iter: 63 Computation Time: 15
# iter: 64 Computation Time: 15
# iter: 65 Computation Time: 15
# iter: 66 Computation Time: 15
# iter: 67 Computation Time: 15
# iter: 68 Computation Time: 15
# iter: 69 Computation Time: 15
# iter: 70 Computation Time: 15
# iter: 71 Computation Time: 15
# iter: 72 Computation Time: 15
# iter: 73 Computation Time: 15
# iter: 74 Computation Time: 15
# iter: 75 Computation Time: 15
# iter: 76 Computation Time: 15
# iter: 77 Computation Time: 15
# iter: 78 Computation Time: 15
# iter: 79 Computation Time: 15
# iter: 80 Computation Time: 15
# iter: 81 Computation Time: 15
# iter: 82 Computation Time: 15
# iter: 83 Computation Time: 15
# iter: 84 Computation Time: 15
# iter: 85 Computation Time: 15
# iter: 86 Computation Time: 15
# iter: 87 Computation Time: 15
# iter: 88 Computation Time: 15
# iter: 89 Computation Time: 15
# iter: 90 Computation Time: 15
# iter: 91 Computation Time: 15
# iter: 92 Computation Time: 15
# iter: 93 Computation Time: 15
# iter: 94 Computation Time: 15
# iter: 95 Computation Time: 15
# iter: 96 Computation Time: 15
# iter: 97 Computation Time: 15
# iter: 98 Computation Time: 15
# iter: 99 Computation Time: 15
# iter: 100 Computation Time: 15
# iter: 101 Computation Time: 15
# iter: 102 Computation Time: 15
# iter: 103 Computation Time: 15
# iter: 104 Computation Time: 15
# iter: 105 Computation Time: 15
# iter: 106 Computation Time: 15
# iter: 107 Computation Time: 15
# iter: 108 Computation Time: 15
# iter: 109 Computation Time: 15
# iter: 110 Computation Time: 15
# iter: 111 Computation Time: 15
# iter: 112 Computation Time: 15
# iter: 113 Computation Time: 15
# iter: 114 Computation Time: 15
# iter: 115 Computation Time: 15
# iter: 116 Computation Time: 15
# iter: 117 Computation Time: 15
# iter: 118 Computation Time: 15
# iter: 119 Computation Time: 15
# iter: 120 Computation Time: 15
# iter: 121 Computation Time: 15
# iter: 122 Computation Time: 15
# iter: 123 Computation Time: 15
# iter: 124 Computation Time: 15
# iter: 125 Computation Time: 15
# iter: 126 Computation Time: 15
# iter: 127 Computation Time: 15
# iter: 128 Computation Time: 15
# iter: 129 Computation Time: 15
# iter: 130 Computation Time: 15
# iter: 131 Computation Time: 15
# iter: 132 Computation Time: 15
# iter: 133 Computation Time: 15
# iter: 134 Computation Time: 15
# iter: 135 Computation Time: 15
# iter: 136 Computation Time: 15
# iter: 137 Computation Time: 15
# iter: 138 Computation Time: 15
# iter: 139 Computation Time: 15
# iter: 140 Computation Time: 15
# iter: 141 Computation Time: 15
# iter: 142 Computation Time: 15
# iter: 143 Computation Time: 15
# iter: 144 Computation Time: 15
# iter: 145 Computation Time: 15
# iter: 146 Computation Time: 15
# iter: 147 Computation Time: 15
# iter: 148 Computation Time: 15
# iter: 149 Computation Time: 15
# iter: 150 Computation Time: 15
# iter: 151 Computation Time: 15
# iter: 152 Computation Time: 15
# iter: 153 Computation Time: 15
# iter: 154 Computation Time: 15
# iter: 155 Computation Time: 15
# iter: 156 Computation Time: 15
# iter: 157 Computation Time: 15
# iter: 158 Computation Time: 15
# iter: 159 Computation Time: 15
# iter: 160 Computation Time: 15
# iter: 161 Computation Time: 15
# iter: 162 Computation Time: 15
# iter: 163 Computation Time: 15
# iter: 164 Computation Time: 15
# iter: 165 Computation Time: 15
# iter: 166 Computation Time: 15
# iter: 167 Computation Time: 15
# iter: 168 Computation Time: 15
# iter: 169 Computation Time: 15
# iter: 170 Computation Time: 15
# iter: 171 Computation Time: 15
# iter: 172 Computation Time: 15
# iter: 173 Computation Time: 15
# iter: 174 Computation Time: 15
# iter: 175 Computation Time: 15
# iter: 176 Computation Time: 15
# iter: 177 Computation Time: 15
# iter: 178 Computation Time: 15
# iter: 179 Computation Time: 15
# iter: 180 Computation Time: 15
# iter: 181 Computation Time: 15
# iter: 182 Computation Time: 15
# iter: 183 Computation Time: 15
# iter: 184 Computation Time: 15
# iter: 185 Computation Time: 15
# iter: 186 Computation Time: 15
# iter: 187 Computation Time: 15
# iter: 188 Computation Time: 15
# iter: 189 Computation Time: 15
# iter: 190 Computation Time: 15
# iter: 191 Computation Time: 15
# iter: 192 Computation Time: 15
# iter: 193 Computation Time: 15
# ...
# iter: 80 Computation Time: 40
# iter: 81 Computation Time: 40
# iter: 82 Computation Time: 40
# iter: 83 Computation Time: 40
# iter: 84 Computation Time: 40
# iter: 85 Computation Time: 40
# iter: 86 Computation Time: 40
# iter: 87 Computation Time: 40
# iter: 88 Computation Time: 40
# iter: 89 Computation Time: 40
# iter: 90 Computation Time: 40
# iter: 91 Computation Time: 40
# iter: 92 Computation Time: 40
# iter: 93 Computation Time: 40
# iter: 94 Computation Time: 40
# iter: 95 Computation Time: 40
# iter: 96 Computation Time: 40
# iter: 97 Computation Time: 40
# iter: 98 Computation Time: 40
# iter: 99 Computation Time: 40
# iter: 100 Computation Time: 40
# iter: 101 Computation Time: 40
# iter: 102 Computation Time: 40
# iter: 103 Computation Time: 40
# iter: 104 Computation Time: 40
# iter: 105 Computation Time: 40
# iter: 106 Computation Time: 40
# iter: 107 Computation Time: 40
# iter: 108 Computation Time: 40
# iter: 109 Computation Time: 40
# iter: 110 Computation Time: 40
# iter: 111 Computation Time: 40
# iter: 112 Computation Time: 40
# iter: 113 Computation Time: 40
# iter: 114 Computation Time: 40
# iter: 115 Computation Time: 40
# iter: 116 Computation Time: 40
# iter: 117 Computation Time: 40
# iter: 118 Computation Time: 40
# iter: 119 Computation Time: 40
# iter: 120 Computation Time: 40
# iter: 121 Computation Time: 40
# iter: 122 Computation Time: 40
# iter: 123 Computation Time: 40
# iter: 124 Computation Time: 40
# iter: 125 Computation Time: 40
# iter: 126 Computation Time: 40
# iter: 127 Computation Time: 40
# iter: 128 Computation Time: 40
# iter: 129 Computation Time: 40
# iter: 130 Computation Time: 40
# iter: 131 Computation Time: 40
# iter: 132 Computation Time: 40
# iter: 133 Computation Time: 40
# iter: 134 Computation Time: 40
# iter: 135 Computation Time: 40
# iter: 136 Computation Time: 40
# iter: 137 Computation Time: 40
# iter: 138 Computation Time: 40
# iter: 139 Computation Time: 40
# iter: 140 Computation Time: 40
# iter: 141 Computation Time: 40
# iter: 142 Computation Time: 40
# iter: 143 Computation Time: 40
# iter: 144 Computation Time: 40
# iter: 145 Computation Time: 40
# iter: 146 Computation Time: 40
# iter: 147 Computation Time: 40
# iter: 148 Computation Time: 40
# iter: 149 Computation Time: 40
# iter: 150 Computation Time: 40
# iter: 151 Computation Time: 40
# iter: 152 Computation Time: 40
# iter: 153 Computation Time: 40
# iter: 154 Computation Time: 40
# iter: 155 Computation Time: 40
# iter: 156 Computation Time: 40
# iter: 157 Computation Time: 40
# iter: 158 Computation Time: 40
# iter: 159 Computation Time: 40
# iter: 160 Computation Time: 40
# iter: 161 Computation Time: 40
# iter: 162 Computation Time: 40
# iter: 163 Computation Time: 40
# iter: 164 Computation Time: 40
# iter: 165 Computation Time: 40
# iter: 166 Computation Time: 40
# iter: 167 Computation Time: 40
# iter: 168 Computation Time: 40
# iter: 169 Computation Time: 40
# iter: 170 Computation Time: 40
# iter: 171 Computation Time: 40
# iter: 172 Computation Time: 40
# iter: 173 Computation Time: 40
# iter: 174 Computation Time: 40
# iter: 175 Computation Time: 40
# iter: 176 Computation Time: 40
# iter: 177 Computation Time: 40
# iter: 178 Computation Time: 40
# iter: 179 Computation Time: 40
# iter: 180 Computation Time: 40
# iter: 181 Computation Time: 40
# iter: 182 Computation Time: 40
# iter: 183 Computation Time: 40
# iter: 184 Computation Time: 40
# iter: 185 Computation Time: 40
# iter: 186 Computation Time: 40
# iter: 187 Computation Time: 40
# iter: 188 Computation Time: 40
# iter: 189 Computation Time: 40
# iter: 190 Computation Time: 40
# iter: 191 Computation Time: 40
# iter: 192 Computation Time: 40
# iter: 193 Computation Time: 40
# iter: 194 Computation Time: 40
# iter: 195 Computation Time: 40
# iter: 196 Computation Time: 40
# iter: 197 Computation Time: 40
# iter: 198 Computation Time: 40
# iter: 199 Computation Time: 40
# total time spent:  5953.655644416809
# iter: 0 Computation Time: 45
# iter: 1 Computation Time: 45
# iter: 2 Computation Time: 45
# iter: 3 Computation Time: 45
# iter: 4 Computation Time: 45
# iter: 5 Computation Time: 45
# iter: 6 Computation Time: 45
# iter: 7 Computation Time: 45
# iter: 8 Computation Time: 45
# iter: 9 Computation Time: 45
# iter: 10 Computation Time: 45
# iter: 11 Computation Time: 45
# iter: 12 Computation Time: 45
# iter: 13 Computation Time: 45
# iter: 14 Computation Time: 45
# iter: 15 Computation Time: 45
# iter: 16 Computation Time: 45
# iter: 17 Computation Time: 45
# iter: 18 Computation Time: 45
# iter: 19 Computation Time: 45
# iter: 20 Computation Time: 45
# iter: 21 Computation Time: 45
# iter: 22 Computation Time: 45
# iter: 23 Computation Time: 45
# iter: 24 Computation Time: 45
# iter: 25 Computation Time: 45
# iter: 26 Computation Time: 45
# iter: 27 Computation Time: 45
# iter: 28 Computation Time: 45
# iter: 29 Computation Time: 45
# iter: 30 Computation Time: 45
# iter: 31 Computation Time: 45
# iter: 32 Computation Time: 45
# iter: 33 Computation Time: 45
# iter: 34 Computation Time: 45
# iter: 35 Computation Time: 45
# iter: 36 Computation Time: 45
# iter: 37 Computation Time: 45
# iter: 38 Computation Time: 45
# iter: 39 Computation Time: 45
# iter: 40 Computation Time: 45
# iter: 41 Computation Time: 45
# iter: 42 Computation Time: 45
# iter: 43 Computation Time: 45
# iter: 44 Computation Time: 45
# iter: 45 Computation Time: 45
# iter: 46 Computation Time: 45
# iter: 47 Computation Time: 45
# iter: 48 Computation Time: 45
# iter: 49 Computation Time: 45
# iter: 50 Computation Time: 45
# iter: 51 Computation Time: 45
# iter: 52 Computation Time: 45
# iter: 53 Computation Time: 45
# iter: 54 Computation Time: 45
# iter: 55 Computation Time: 45
# iter: 56 Computation Time: 45
# iter: 57 Computation Time: 45
# iter: 58 Computation Time: 45
# iter: 59 Computation Time: 45
# iter: 60 Computation Time: 45
# iter: 61 Computation Time: 45
# iter: 62 Computation Time: 45
# iter: 63 Computation Time: 45
# iter: 64 Computation Time: 45
# iter: 65 Computation Time: 45
# iter: 66 Computation Time: 45
# iter: 67 Computation Time: 45
# iter: 68 Computation Time: 45
# iter: 69 Computation Time: 45
# iter: 70 Computation Time: 45
# iter: 71 Computation Time: 45
# iter: 72 Computation Time: 45
# iter: 73 Computation Time: 45
# iter: 74 Computation Time: 45
# iter: 75 Computation Time: 45
# iter: 76 Computation Time: 45
# iter: 77 Computation Time: 45
# iter: 78 Computation Time: 45
# iter: 79 Computation Time: 45
# iter: 80 Computation Time: 45
# iter: 81 Computation Time: 45
# iter: 82 Computation Time: 45
# iter: 83 Computation Time: 45
# iter: 84 Computation Time: 45
# iter: 85 Computation Time: 45
# iter: 86 Computation Time: 45
# iter: 87 Computation Time: 45
# iter: 88 Computation Time: 45
# iter: 89 Computation Time: 45
# iter: 90 Computation Time: 45
# iter: 91 Computation Time: 45
# iter: 92 Computation Time: 45
# iter: 93 Computation Time: 45
# iter: 94 Computation Time: 45
# iter: 95 Computation Time: 45
# iter: 96 Computation Time: 45
# iter: 97 Computation Time: 45
# iter: 98 Computation Time: 45
# iter: 99 Computation Time: 45
# iter: 100 Computation Time: 45
# iter: 101 Computation Time: 45
# iter: 102 Computation Time: 45
# iter: 103 Computation Time: 45
# iter: 104 Computation Time: 45
# iter: 105 Computation Time: 45
# iter: 106 Computation Time: 45
# iter: 107 Computation Time: 45
# iter: 108 Computation Time: 45
# iter: 109 Computation Time: 45
# iter: 110 Computation Time: 45
# iter: 111 Computation Time: 45
# iter: 112 Computation Time: 45
# iter: 113 Computation Time: 45
# iter: 114 Computation Time: 45
# iter: 115 Computation Time: 45
# iter: 116 Computation Time: 45
# iter: 117 Computation Time: 45
# iter: 118 Computation Time: 45
# iter: 119 Computation Time: 45
# iter: 120 Computation Time: 45
# iter: 121 Computation Time: 45
# iter: 122 Computation Time: 45
# iter: 123 Computation Time: 45
# iter: 124 Computation Time: 45
# iter: 125 Computation Time: 45
# iter: 126 Computation Time: 45
# iter: 127 Computation Time: 45
# iter: 128 Computation Time: 45
# iter: 129 Computation Time: 45
# iter: 130 Computation Time: 45
# iter: 131 Computation Time: 45
# iter: 132 Computation Time: 45
# iter: 133 Computation Time: 45
# iter: 134 Computation Time: 45
# iter: 135 Computation Time: 45
# iter: 136 Computation Time: 45
# iter: 137 Computation Time: 45
# iter: 138 Computation Time: 45
# iter: 139 Computation Time: 45
# iter: 140 Computation Time: 45
# iter: 141 Computation Time: 45
# iter: 142 Computation Time: 45
# iter: 143 Computation Time: 45
# iter: 144 Computation Time: 45
# iter: 145 Computation Time: 45
# iter: 146 Computation Time: 45
# iter: 147 Computation Time: 45
# iter: 148 Computation Time: 45
# iter: 149 Computation Time: 45
# iter: 150 Computation Time: 45
# iter: 151 Computation Time: 45
# iter: 152 Computation Time: 45
# iter: 153 Computation Time: 45
# iter: 154 Computation Time: 45
# iter: 155 Computation Time: 45
# iter: 156 Computation Time: 45
# iter: 157 Computation Time: 45
# iter: 158 Computation Time: 45
# iter: 159 Computation Time: 45
# iter: 160 Computation Time: 45
# iter: 161 Computation Time: 45
# iter: 162 Computation Time: 45
# iter: 163 Computation Time: 45
# iter: 164 Computation Time: 45
# iter: 165 Computation Time: 45
# iter: 166 Computation Time: 45
# iter: 167 Computation Time: 45
# iter: 168 Computation Time: 45
# iter: 169 Computation Time: 45
# iter: 170 Computation Time: 45
# iter: 171 Computation Time: 45
# iter: 172 Computation Time: 45
# iter: 173 Computation Time: 45
# iter: 174 Computation Time: 45
# iter: 175 Computation Time: 45
# iter: 176 Computation Time: 45
# iter: 177 Computation Time: 45
# iter: 178 Computation Time: 45
# iter: 179 Computation Time: 45
# iter: 180 Computation Time: 45
# iter: 181 Computation Time: 45
# iter: 182 Computation Time: 45
# iter: 183 Computation Time: 45
# iter: 184 Computation Time: 45
# iter: 185 Computation Time: 45
# iter: 186 Computation Time: 45
# iter: 187 Computation Time: 45
# iter: 188 Computation Time: 45
# iter: 189 Computation Time: 45
# iter: 190 Computation Time: 45
# iter: 191 Computation Time: 45
# iter: 192 Computation Time: 45
# iter: 193 Computation Time: 45
# iter: 194 Computation Time: 45
# iter: 195 Computation Time: 45
# iter: 196 Computation Time: 45
# iter: 197 Computation Time: 45
# iter: 198 Computation Time: 45
# iter: 199 Computation Time: 45
# total time spent:  5716.66185593605
# iter: 0 Computation Time: 50
# iter: 1 Computation Time: 50
# iter: 2 Computation Time: 50
# iter: 3 Computation Time: 50
# iter: 4 Computation Time: 50
# iter: 5 Computation Time: 50
# iter: 6 Computation Time: 50
# iter: 7 Computation Time: 50
# iter: 8 Computation Time: 50
# iter: 9 Computation Time: 50
# iter: 10 Computation Time: 50
# iter: 11 Computation Time: 50
# iter: 12 Computation Time: 50
# iter: 13 Computation Time: 50
# iter: 14 Computation Time: 50
# iter: 15 Computation Time: 50
# iter: 16 Computation Time: 50
# iter: 17 Computation Time: 50
# iter: 18 Computation Time: 50
# iter: 19 Computation Time: 50
# iter: 20 Computation Time: 50
# iter: 21 Computation Time: 50
# iter: 22 Computation Time: 50
# iter: 23 Computation Time: 50
# iter: 24 Computation Time: 50
# iter: 25 Computation Time: 50
# iter: 26 Computation Time: 50
# iter: 27 Computation Time: 50
# iter: 28 Computation Time: 50
# iter: 29 Computation Time: 50
# iter: 30 Computation Time: 50
# iter: 31 Computation Time: 50
# iter: 32 Computation Time: 50
# iter: 33 Computation Time: 50
# iter: 34 Computation Time: 50
# iter: 35 Computation Time: 50
# iter: 36 Computation Time: 50
# iter: 37 Computation Time: 50
# iter: 38 Computation Time: 50
# iter: 39 Computation Time: 50
# iter: 40 Computation Time: 50
# iter: 41 Computation Time: 50
# iter: 42 Computation Time: 50
# iter: 43 Computation Time: 50
# iter: 44 Computation Time: 50
# iter: 45 Computation Time: 50
# iter: 46 Computation Time: 50
# iter: 47 Computation Time: 50
# iter: 48 Computation Time: 50
# iter: 49 Computation Time: 50
# iter: 50 Computation Time: 50
# iter: 51 Computation Time: 50
# iter: 52 Computation Time: 50
# iter: 53 Computation Time: 50
# iter: 54 Computation Time: 50
# iter: 55 Computation Time: 50
# iter: 56 Computation Time: 50
# iter: 57 Computation Time: 50
# iter: 58 Computation Time: 50
# iter: 59 Computation Time: 50
# iter: 60 Computation Time: 50
# iter: 61 Computation Time: 50
# iter: 62 Computation Time: 50
# iter: 63 Computation Time: 50
# iter: 64 Computation Time: 50
# iter: 65 Computation Time: 50
# iter: 66 Computation Time: 50
# iter: 67 Computation Time: 50
# iter: 68 Computation Time: 50
# iter: 69 Computation Time: 50
# iter: 70 Computation Time: 50
# iter: 71 Computation Time: 50
# iter: 72 Computation Time: 50
# iter: 73 Computation Time: 50
# iter: 74 Computation Time: 50
# iter: 75 Computation Time: 50
# iter: 76 Computation Time: 50
# iter: 77 Computation Time: 50
# iter: 78 Computation Time: 50
# iter: 79 Computation Time: 50
# iter: 80 Computation Time: 50
# iter: 81 Computation Time: 50
# iter: 82 Computation Time: 50
# iter: 83 Computation Time: 50
# iter: 84 Computation Time: 50
# iter: 85 Computation Time: 50
# iter: 86 Computation Time: 50
# iter: 87 Computation Time: 50
# iter: 88 Computation Time: 50
# iter: 89 Computation Time: 50
# iter: 90 Computation Time: 50
# iter: 91 Computation Time: 50
# iter: 92 Computation Time: 50
# iter: 93 Computation Time: 50
# iter: 94 Computation Time: 50
# iter: 95 Computation Time: 50
# iter: 96 Computation Time: 50
# iter: 97 Computation Time: 50
# iter: 98 Computation Time: 50
# iter: 99 Computation Time: 50
# iter: 100 Computation Time: 50
# iter: 101 Computation Time: 50
# iter: 102 Computation Time: 50
# iter: 103 Computation Time: 50
# iter: 104 Computation Time: 50
# iter: 105 Computation Time: 50
# iter: 106 Computation Time: 50
# iter: 107 Computation Time: 50
# iter: 108 Computation Time: 50
# iter: 109 Computation Time: 50
# iter: 110 Computation Time: 50
# iter: 111 Computation Time: 50
# iter: 112 Computation Time: 50
# iter: 113 Computation Time: 50
# iter: 114 Computation Time: 50
# iter: 115 Computation Time: 50
# iter: 116 Computation Time: 50
# iter: 117 Computation Time: 50
# iter: 118 Computation Time: 50
# iter: 119 Computation Time: 50
# iter: 120 Computation Time: 50
# iter: 121 Computation Time: 50
# iter: 122 Computation Time: 50
# iter: 123 Computation Time: 50
# iter: 124 Computation Time: 50
# iter: 125 Computation Time: 50
# iter: 126 Computation Time: 50
# iter: 127 Computation Time: 50
# iter: 128 Computation Time: 50
# iter: 129 Computation Time: 50
# iter: 130 Computation Time: 50
# iter: 131 Computation Time: 50
# iter: 132 Computation Time: 50
# iter: 133 Computation Time: 50
# iter: 134 Computation Time: 50
# iter: 135 Computation Time: 50
# iter: 136 Computation Time: 50
# iter: 137 Computation Time: 50
# iter: 138 Computation Time: 50
# iter: 139 Computation Time: 50
# iter: 140 Computation Time: 50
# iter: 141 Computation Time: 50
# iter: 142 Computation Time: 50
# iter: 143 Computation Time: 50
# iter: 144 Computation Time: 50
# iter: 145 Computation Time: 50
# iter: 146 Computation Time: 50
# iter: 147 Computation Time: 50
# iter: 148 Computation Time: 50
# iter: 149 Computation Time: 50
# iter: 150 Computation Time: 50
# iter: 151 Computation Time: 50
# iter: 152 Computation Time: 50
# iter: 153 Computation Time: 50
# iter: 154 Computation Time: 50
# iter: 155 Computation Time: 50
# iter: 156 Computation Time: 50
# iter: 157 Computation Time: 50
# iter: 158 Computation Time: 50
# iter: 159 Computation Time: 50
# iter: 160 Computation Time: 50
# iter: 161 Computation Time: 50
# iter: 162 Computation Time: 50
# iter: 163 Computation Time: 50
# iter: 164 Computation Time: 50
# iter: 165 Computation Time: 50
# iter: 166 Computation Time: 50
# iter: 167 Computation Time: 50
# iter: 168 Computation Time: 50
# iter: 169 Computation Time: 50
# iter: 170 Computation Time: 50
# iter: 171 Computation Time: 50
# iter: 172 Computation Time: 50
# iter: 173 Computation Time: 50
# iter: 174 Computation Time: 50
# iter: 175 Computation Time: 50
# iter: 176 Computation Time: 50
# iter: 177 Computation Time: 50
# iter: 178 Computation Time: 50
# iter: 179 Computation Time: 50
# iter: 180 Computation Time: 50
# iter: 181 Computation Time: 50
# iter: 182 Computation Time: 50
# iter: 183 Computation Time: 50
# iter: 184 Computation Time: 50
# iter: 185 Computation Time: 50
# iter: 186 Computation Time: 50
# iter: 187 Computation Time: 50
# iter: 188 Computation Time: 50
# iter: 189 Computation Time: 50
# iter: 190 Computation Time: 50
# iter: 191 Computation Time: 50
# iter: 192 Computation Time: 50
# iter: 193 Computation Time: 50
# iter: 194 Computation Time: 50
# iter: 195 Computation Time: 50
# iter: 196 Computation Time: 50
# iter: 197 Computation Time: 50
# iter: 198 Computation Time: 50
# iter: 199 Computation Time: 50
# total time spent:  5793.529705047607

# %%
print(success_vec_waitGo)
print(success_vec_RRTC)
print(sum(WG_path_length_list)/len(WG_path_length_list))
print(sum(RRTC_path_length_list)/len(RRTC_path_length_list))
# Out:
# [0.0, 0.01, 0.075, 0.15, 0.345, 0.46, 0.53, 0.7, 0.87, 0.855, 0.9, 0.925, 0.875, 0.915, 0.935]
# [0.0, 0.005, 0.065, 0.19, 0.23, 0.395, 0.345, 0.645, 0.71, 0.79, 0.765, 0.82, 0.845, 0.845, 0.805]
# 40.817006797666885
# 43.1601984653826

# %%
WG_length_list = []
WG_time_list = []
RRTC_length_list = []
RRTC_time_list = []

for i in range(len(compTimeVec)):
    WG_length_tmep = WG_path['length'][str(i)]
    WG_time_tmep = WG_path['time'][str(i)]
    RRTC_length_tmep = RRTC_path['length'][str(i)]
    RRTC_time_tmep = RRTC_path['time'][str(i)]

    if len(WG_length_tmep) > 0:
        WG_length_temp = sum(WG_length_tmep)/len(WG_length_tmep)
    else:
        WG_length_temp = 0
    
    if len(WG_time_tmep) > 0:
        WG_time_temp = sum(WG_time_tmep)/len(WG_time_tmep)
    else:
        WG_time_temp = 0

    if len(RRTC_length_tmep) > 0:
        RRTC_length_temp = sum(RRTC_length_tmep)/len(RRTC_length_tmep)
    else:
        RRTC_length_temp = 0
    
    if len(RRTC_time_tmep) > 0:
        RRTC_time_temp = sum(RRTC_time_tmep)/len(RRTC_time_tmep)
    else:
        RRTC_time_temp = 0
    

    WG_length_list.append(WG_length_temp)
    WG_time_list.append(WG_time_temp)
    RRTC_length_list.append(RRTC_length_temp)
    RRTC_time_list.append(RRTC_time_temp)

fig = plt.figure()
ax = plt.subplot(2,1,1)
plt.plot(compTimeVec, WG_length_list, '-r')
plt.plot(compTimeVec, RRTC_length_list, '--b', alpha=0.5)
# plt.legend(['RRT-Connect with Wait-Go', 'RRT-Connect'])
plt.grid(which='major', color='#DDDDDD', linewidth=0.8)
plt.grid(which='minor', color='k', linewidth=0.25)
# plt.xlabel('Computation Time')
plt.ylabel('Average Path Length')
ax.set_xscale('log')


ax = plt.subplot(2,1,2)
plt.plot(compTimeVec, WG_time_list, '-r')
plt.plot(compTimeVec, RRTC_time_list, '--b', alpha=0.5)
# plt.legend(['RRT-Connect with Wait-Go', 'RRT-Connect'])
plt.grid(which='major', color='#DDDDDD', linewidth=0.8)
plt.grid(which='minor', color='k', linewidth=0.25)
plt.xlabel('Computation Time')
plt.ylabel('Average Path Time')
ax.set_xscale('log')

print(WG_length_list)
print(RRTC_length_list)
# Out:
# [0, 17.462126109724643, 23.088150916151697, 31.07681966986628, 32.47240542353652, 33.80010578515433, 34.24203090236067, 36.77185223786982, 36.68971208897543, 38.231638784072466, 37.428607935412316, 37.20381932660753, 39.54859136927179, 37.88444340862537, 40.817006797666885]
# [0, 6.431266643663161, 27.392288394311056, 29.659937084861735, 28.236398075209255, 33.21822522902108, 35.98961603123476, 37.69814235735231, 38.5648983502753, 39.42276795372219, 38.709489224431024, 42.200458105498825, 40.08211020272706, 40.19813176779544, 43.1601984653826]

# %%
fig = plt.figure()
ax = plt.subplot(1,1,1)
plt.plot(compTimeVec, success_vec_waitGo, '-r')
plt.plot(compTimeVec, success_vec_RRTC, '--b', alpha=0.5)
# plt.legend(['RRT-Connect with Wait-Go', 'RRT-Connect'])
plt.grid(which='major', color='#DDDDDD', linewidth=0.8)
plt.grid(which='minor', color='k', linewidth=0.25)
plt.xlabel('Computation Time')
plt.ylabel('Success Rate')
ax.set_xscale('log')

# %%
afdasfdafasfsa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/jeff/git/ros2_ws/src/cognis_UAM/script/R2T2VrCtr/R2T2_Performance_Comparison.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/home/jeff/git/ros2_ws/src/cognis_UAM/script/R2T2VrCtr/R2T2_Performance_Comparison.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> afdasfdafasfsa
#
# NameError: name 'afdasfdafasfsa' is not defined

# %%
wait_switch = [0.85, 0.1, 0.05]
RRTC_switch = [0.95, 0,   0.05]
success_vec_waitGo = []
success_vec_RRTC = []
avg_compTime_vec_waitGo = []
avg_compTime_vec_RRTC = []

for ti in compTimeVec:
    # Single camera example, surveying final location xfin
    # Camera Position
    cam_x = np.array([7.5])
    # cam_y = np.array([rn.uniform(-10, 10)])
    cam_y = np.array([rn.uniform(-5, 5)])
    cam_dict = {}
    cam_dict['n'] = len(cam_x)
    cam_dict['x'] = cam_x
    cam_dict['y'] = cam_y

    # Camera Spec
    tilt_limit = np.array([np.pi, 0]) #[upper, lower]
    fov_ang = 20#np.deg2rad(rn.uniform(10, 30))
    fov_rng = 7.5 #[m]
    cam_period = t[0]
    cam_increment = t[1]
    cam_dict['spec'] = {}
    cam_dict['spec']['bound'] = tilt_limit
    cam_dict['spec']['fov'] = [fov_ang, fov_rng]
    cam_dict['spec']['cam_time'] = [cam_period, cam_increment]

    start = time.time()
    print('Computation Time: ', ti)
    success_waitGo = 0
    success_RRTC = 0
    counter = 0
    for mc_ii in range(mc_iter):
        # print('iter: ', counter)
        # path_obtained, RRTWait = test.R2T2_2D(ti, wait_switch)
        path_obtained_waitGo, compTime_waitGo, WG_exec_time_dict = test.R2T2_2D(ti, wait_switch)
        success_waitGo += path_obtained_waitGo

        path_obtained_RRTC, compTime_RRTC, RRTC_exec_time_dict = test.R2T2_2D(ti, RRTC_switch)
        success_RRTC += path_obtained_RRTC
        counter += 1
    success_vec_waitGo.append(success_waitGo/mc_iter)
    success_vec_RRTC.append(success_RRTC/mc_iter)
    print('total time spent: ', time.time()-start)
    avg_compTime_vec_waitGo.append(compTime_waitGo)
    avg_compTime_vec_RRTC.append(compTime_RRTC)

fig = plt.figure()
plt.plot(compTimeVec, success_vec_waitGo, '-r')
plt.plot(compTimeVec, success_vec_RRTC, '-b')
plt.legend(['RRT-Connect with Wait-Go', 'RRT-Connect'])
plt.grid()
plt.xlabel('Computation Time')
plt.ylabel('Success Rate')
# Out:
# Computation Time:  0.1
# total time spent:  5.2439141273498535
# Computation Time:  1
# total time spent:  41.027429819107056
# Computation Time:  5
# total time spent:  180.54600358009338
# Computation Time:  10
# total time spent:  306.1093153953552
# Computation Time:  20
# total time spent:  381.8490660190582
# Computation Time:  30
# total time spent:  536.2684502601624
# Text(0, 0.5, 'Success Rate')
